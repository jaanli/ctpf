# %%
# %matplotlib inline

# %% [markdown]
# goal:
#
# an analysis with specific papers.
# look at interdisciplinary papers, within discipline papers, and any
# new post-hoc statistics that you think could be interesting.  for how
# to do this, see our papers on collaborative topic modeling and my talk
# about it (all on my website).  ask me if you are confused how to do
# this.  i'm also interested in how this model fails on this data.  (we
# know it must.)
#
# a super thorough look at
# this model would also consider the held out predictions and specific
# users.  you would understand their interests via their clicks, and how
# the model has captured or not captured them.

# %%
# replicate the functionality of explore-coll-msd-tm.R for posterity and general ease of use
import numpy as np
import cPickle as pickle
import pandas as pd
import matplotlib
import h5py
matplotlib.style.use('ggplot')
import matplotlib.pyplot as plt
from IPython.display import display



#fitPath = "/scratch/shared/music_project/jaan/ctpf-fits/collabtm/src/nusers1128835-ndocs202994-nvocab256-k50-batch-bin-vb-fa-ldainit/"

# fit path
fitPath = '/home/waldorf/altosaar/projects/arxiv/fit/2015-11-10-pmf-categorywise_true-converge_out_category_first/'

# output file
fName = fitPath + 'arxiv-categories-pf-2.txt'

# maps
in_dir = '/home/statler/lcharlin/arxiv/dat/dataset_2003-2012_clean/'
id2arxiv_info = pd.read_csv(in_dir + 'items_arxiv_info.tsv', header=None, delimiter='\t', names=['arxiv_id', 'categories', 'title', 'date'])

# %% [markdown]
# check that we have the right categories in the map:

# %%
document_category_dummies = id2arxiv_info['categories'].str.join(sep='').str.get_dummies(sep=' ')
category_list = list(document_category_dummies.columns)

# %%
observed_categories = document_category_dummies.as_matrix().astype(np.float32)

# %%
topic2category = {k:category for k, category in enumerate(category_list)}

# %% [markdown]
# # NB: here theta = topic matrix, but in my fits, theta = user prefs matrix!

# %%
# # load theta
# for fixed (observed) theta the code adds a small prior value (0.0308...) to each entry
# tName = fitPath + 'theta.tsv'
# # skip first two cols, and first row
# theta = pd.read_csv(tName, delimiter='\t', header=None).iloc[0:,2:]

# this is the fixed theta (according to arxiv category)
fitFile = fitPath + 'fit.h5'
h5f = h5py.File(fitFile, 'r')
theta_t = h5f['Eb_t'][:]
theta = theta_t.T
#epsilon_t = h5f['Eba_t']
beta_t = h5f['Et_t'][:]
beta = beta_t.T
#theta = observed_categories #pickle.load(open(tName, 'rb'))#pd.read_csv(tName, delimiter=' ', header=None)

# %%
#theta = theta.as_matrix()
# normalize
# def normalizeRow(row):
#     return row / np.sum(row)
#theta.apply(normalizeRow, axis=0)

# num topics
k = len(theta[0])

# %%
epsilon = np.zeros_like(theta)

# %%
# load id2word
#mapName = '/scratch/shared/music_project/jaan/lda-fits/dat/id2word.pickle'
#id2word = pickle.load(open(mapName, 'rb'))

th_ep = theta + epsilon
th_ep_rs = np.sum(th_ep,axis=1)

# %%
id2arxiv_info.index = range(0, len(id2arxiv_info))

# %%
id2item_dict = id2arxiv_info.to_dict()

id2title = id2item_dict['title']
id2title[0] = 'dummy title'
def normalizeRow(row):
    return row / np.sum(row)
normth = np.apply_along_axis(normalizeRow, axis=1, arr=theta)
#normth = theta

# %%
normth[0].sum()
# Out:
# 0.99999994

# %% [markdown]
# now we're ready to check if the observed topics match what's in our article id to title/arxiv id map. it checks out:

# %%
print np.where(theta[3434] == 1)
print topic2category[np.where(theta[3434] == 1)[0][0]]

print id2title[3434]
# Out:
# (array([], dtype=int64),)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-13ba9aadedf4> in <module>()
#       1 print np.where(theta[3434] == 1)
# ----> 2 print topic2category[np.where(theta[3434] == 1)[0][0]]
#       3
#       4 print id2title[3434]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
topic2category[26], topic2category[19]
# Out:
# ('cond-mat.supr-con', 'cond-mat.mes-hall')

# %%
print th_ep.shape, th_ep_rs.shape
# Out:
# (806139, 166) (806139,)

# %%
# number of articles in category 0.
np.where(normth[:,0] > 0)[0].shape
# Out:
# (806139,)

# %%
#working
def similarArticles(docId, theta, n):
    sqrt_normed_theta = np.sqrt(normth[docId])
    a = np.sum(np.power(np.sqrt(normththeta) - sqrt_normed_theta,2),axis=1)
    # this was in reverse
    top = np.argsort(a)
    for topId in top[0:n]:
        print "%0.3f  %s" %(a[topId],id2title[topId])

#working
def topArticles(k,normth=normth,n=10, verbose=False):
    top = np.argsort(normth[:,k])[::-1]
    lines = ["%0.3f  %s" %(normth[topId,k],id2title[topId]) for topId in top[0:n]]
    if verbose:
        for line in lines:
            print line
    return lines
    #for topId in top[0:n]:
        #print "%0.3f  %s" %(normth[topId,k],id2title[topId]))
        
#working! mistake was that i added normalized theta to eps for th_ep.
def inFieldArticles(k,th_ep=th_ep,normth=normth,n=10,prop=0.15):
    ind = np.where(normth[:,k] > prop)
    th_ep_ind = th_ep[ind,k][0]
    top = np.argsort(th_ep_ind)[::-1]
    return ["%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    #for topId in top[0:n]:
     #   print "%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]]) 
        
#working
def outFieldArticles(k, th_ep=th_ep, normth=normth, n=10, prop=0.05):
    ind = np.where(normth[:,k] < prop)
    th_ep_ind = th_ep[ind,k][0]
    top = np.argsort(th_ep_ind)[::-1]
    return ["%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    #for topId in top[0:n]:
     #   print "%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]])

#working
def interFieldArticles(k, rs = th_ep_rs, th_ep = th_ep, n = 10, prop = 0.15):
    ind = np.where(normth[:,k] > prop)
    rs_ind = rs[ind]
    th_ep_ind = th_ep[ind,k][0]
    score = rs_ind - th_ep_ind
    top = np.argsort(score)[::-1]
    return ["%0.3f  %s" %(score[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    #for topId in top[0:n]:
    #    print "%0.3f  %s" %(score[topId],id2title[ind[0][topId]])

# %% [markdown]
# look at all top articles in each topic

# %%
for k in topic2category.keys():
    print '{}'.format(topic2category[k])
    topArticles(k, verbose=True)
    print '==============='
# Out:
# acc-phys
# 0.999  Ultrashort Laser-pulse Diagnostics for Detection of Ordering within an Ion beam
# 0.998  Muon Colliders
# 0.998  Renormalization Group Approach to the Beam-Beam Interaction in Circular Colliders
# 0.998  The charged beam dumps for the international linear collider
# 0.998  Recent MARS15 developments: nuclide inventory, DPA and gas production
# 0.998  Laser cooling of electron beams for linear colliders
# 0.998  Hybrid Rings of Fixed 8T Superconducting Magnets and Iron Magnets Rapidly Cycling between -2T and +2T for a Muon Collider
# 0.998  Profile Monitor SEM's for the NuMI Beam at FNAL
# 0.998  The Hadron Hose: Continuous Toroidal Focusing for Conventional Neutrino Beams
# 0.998  Acceleration for the mu+ mu- Collider
# ===============
# adap-org
# 0.988  Life-Times of Simulated Traffic Jams
# 0.988  Upper Bounds for the Critical Car Densities in Traffic Flow Problems
# 0.977  The Evolutionary Biology of Ourselves: Unit Requirements and Organizational Change in United States History
# 0.968  Stochastic Coherence in Coupled Map Lattices
# 0.955  Individual Adaption in a Path-Based Simulation of the Freeway Network of Northrhine-Westfalia
# 0.928  Kinetic Theory of Anomalous Transport of SupraThermal Particles
# 0.915  Aging Exponents in Self-Organized Criticality
# 0.912  Propagation of Information in Populations of Self-Replicating Code
# 0.911  Analysis of the Effective Degrees of Freedom in Genetic Algorithms
# 0.893  Mechanisms of synchronization and pattern formation in a lattice of pulse-coupled oscillators
# ===============
# alg-geom
# 0.998  On the String-Theoretic Euler Number of a Class of Absolutely Isolated Singularities
# 0.997  Explicit Resolutions of Double Point Singularities of Surfaces
# 0.997  D-Branes and Hilbert Schemes
# 0.997  Rational curves on Grassmannians: systems theory, reality, and transversality
# 0.996  On Domain-wall/QFT dualities in various dimensions
# 0.996  Superparticles in D>11
# 0.996  M-Theory on Orientifolds of $K_3 \times S^1$
# 0.995  Blow-ups of canonical singularities
# 0.995  Miranda-Persson's problem on extremal elliptic K3 surfaces
# 0.994  Non-transversal colliding singularities in F-theory
# ===============
# ao-sci
# 0.999  Vector Meson Photoproduction in the Soft Dipole Pomeron Model Framework
# 0.999  Evaluation of Giga-bit Ethernet Instrumentation for SalSA Electronics Readout (GEISER)
# 0.999  Compact Symmetric Objects as Radio Flux Density Calibrators
# 0.999  Spin correlation functions and N\'{e}el order in the 2D Heisenberg model: Effects of spatial anisotropy
# 0.999  Evolution of Hole and Spin Dynamics in High Temperature Superconductors within the Small Hole Density Limit of the t-J Model
# 0.999  Monte Carlo simulation of granular fluids
# 0.999  Effects of mirror reflection versus diffusion anisotropy on particle acceleration in oblique shocks
# 0.999  Estimating the Fractal Dimension, K_2-entropy, and the Predictability of the Atmosphere
# 0.999  Large physical spin approach for strongly correlated electrons
# 0.999  Electron gas polarization effect induced by heavy H-like ions of moderate velocities channeled in a silicon crystal
# ===============
# astro-ph
# 0.996  Calculating excitation energies with the help of cumulants
# 0.995  Multiple X-ray reflection from ionized slabs
# 0.994  IRS-TR 12002: Constructing a Short-Low Truth Spectrum of the Standard Star HR 6348
# 0.994  The Distinctive Feature of Weak Interactions and Some of Its Subsequences (Impossibility of Generation of Masses and Absence of the MSW Effect
# 0.993  A Search For Large-Scale Structure at High Redshift
# 0.992  Signals for Supersymmetry at HERA
# 0.992  Stochastic Fermi Acceleration of sub-Relativistic Electrons and Its Role in Impulsive Solar Flares
# 0.988  Use of the European Data Grid software in the framework of the BaBar distributed computing model
# 0.987  Inertial modes of neutron stars with the superfluid core
# 0.986  RX J004717.4-251811: The first eclipsing X-ray binary outside the Local Group
# ===============
# astro-ph.CO
# 1.000  Halo Mass Functions in Early Dark Energy Cosmologies
# 1.000  A Deep Probe of the Galaxy Stellar Mass Functions at z~1-3 with the GOODS NICMOS Survey
# 1.000  Cluster Mass Estimators from CMB Temperature and Polarization Lensing
# 1.000  Observing the clustering properties of galaxy clusters in dynamical dark-energy cosmologies
# 1.000  The diverse hot gas content and dynamics of optically similar low-mass elliptical galaxies
# 1.000  The nuclear X-ray emission of nearby early-type galaxies
# 1.000  The Correlation Function of Optically Selected Galaxy Clusters in the Sloan Digital Sky Survey
# 1.000  Three-Point Correlations in Weak Lensing Surveys: Model Predictions and Applications
# 1.000  Distance, Growth Factor, and Dark Energy Constraints from Photometric Baryon Acoustic Oscillation and Weak Lensing Measurements
# 1.000  Likelihood Functions for Galaxy Cluster Surveys
# ===============
# astro-ph.EP
# 1.000  Detection of a Transiting Low-Density Super-Earth
# 1.000  Characterizing the Cool KOIs III. KOI-961: A Small Star with Large Proper Motion and Three Small Planets
# 1.000  WASP-12b: The hottest transiting planet yet discovered
# 1.000  On stellar limb darkening and exoplanetary transits
# 1.000  Transit infrared spectroscopy of the hot neptune around GJ 436 with the Hubble Space Telescope
# 1.000  Kepler-21b: A 1.6REarth Planet Transiting the Bright Oscillating F Subgiant Star HD 179070
# 1.000  HAT-P-7b: An Extremely Hot Massive Planet Transiting a Bright Star in the Kepler Field
# 1.000  Empirical evidence for tidal evolution in transiting planetary systems
# 1.000  The Transit Light Curve Project. IX. Evidence for a Smaller Radius of the Exoplanet XO-3b
# 1.000  WASP-14b: 7.3 Mj transiting planet in an eccentric orbit
# ===============
# astro-ph.GA
# 1.000  The ACS LCID project. VI. The SFH of the Tucana dSph and the relative ages of the isolated dSph galaxies
# 1.000  Extended Star Clusters in the Remote Halo of the Intriguing Dwarf Galaxy NGC 6822
# 1.000  Determining Photometric Metallicities of dSph Stellar Populations
# 1.000  Star Formation History and Chemical Evolution of the Sextans Dwarf Spheroidal Galaxy
# 1.000  Star formation history of KDG 61 and KDG 64 from spectroscopy and colour-magnitude diagrams
# 0.999  Three newly discovered globular clusters in NGC 6822
# 0.999  Deep Wide-Field Imaging down to the oldest Main Sequence Turnoffs in the Sculptor dwarf spheroidal galaxy
# 0.999  The Globular Cluster System of NGC 4636 and Formation of Globular Clusters in Giant Elliptical Galaxies
# 0.999  LABOCA observations of giant molecular clouds in the south west region of the Small Magellanic Cloud
# 0.999  Lenticular galaxies at the outskirts of the Leo II group: NGC 3599 and NGC 3626
# ===============
# astro-ph.HE
# 1.000  GeV emission from short Gamma-Ray Bursts: the case of GRB 081024B
# 1.000  Constraining the location of the emitting region in Fermi blazars through rapid gamma-ray variability
# 1.000  Polarimetry of the transient relativistic jet of GRB 110328 / Swift J164449.3+573451
# 1.000  GRB spectral parameters within the fireball model
# 1.000  Searching for an EBL attenuation signature in the Fermi/LAT 1st year catalog data
# 1.000  Are Swift Long-Lag Gamma-Ray Bursts in the Local Supercluster?
# 1.000  Correlated optical and gamma emissions from GRB 081126
# 1.000  Deceleration of arbitrarily magnetized GRB ejecta: the complete evolution
# 1.000  The Spectral Energy Distribution of Fermi bright blazars
# 1.000  Lepto-hadronic modelling of blazar emission
# ===============
# astro-ph.IM
# 0.996  The Entropy Index (EI): an Auxiliary Tool to Identify the Occurrence of Interplanetary Magnetic Clouds
# 0.996  Millimeter and Submillimeter Observations from the South Pole
# 0.993  MOSE: zooming on the Meso-NH mesoscale model performances at the surface layer at ESO sites (Paranal and Armazones)
# 0.993  Optical Seeing at Sierra Negra
# 0.992  Total linear polarization in the OH maser W75N: VLBA polarization structure
# 0.992  Mount Pinatubo and Atmospheric Extinction at Mount John University Observatory 1987-94
# 0.990  Long-term study of water masers associated with Young Stellar Objects. II: Analysis
# 0.990  IVOA Recommendation: Observation Data Model Core Components and its Implementation in the Table Access Protocol Version 1.0
# 0.989  Stochastic View of Photon Migration in Turbid Media
# 0.986  Accuracy of the Water Vapour Content Measurements in the Atmosphere Using Optical Methods
# ===============
# astro-ph.SR
# 1.000  Implications of X-ray Observations for Electron Acceleration and Propagation in Solar Flares
# 1.000  Photospheric magnetic field and chromospheric emission
# 1.000  Solar wind speed theory and the nonextensivity of solar corona
# 1.000  Comparison of large-scale flows on the Sun measured by time-distance helioseismology and local correlation tracking technique
# 1.000  Secular Changes in Solar Magnetic Flux Amplification Factor and Prediction of Space Weather
# 1.000  Helicity Observation of Weak and Strong Fields
# 1.000  On the Nature of the Solar Chromosphere
# 1.000  First SDO AIA Observations of a Global Coronal EUV 'Wave': Multiple Components and 'Ripples'
# 1.000  Note on dust trapping in inviscid vortex pairs with unequal strengths
# 1.000  An efficient method for computing the eigenfunctions of the dynamo equation
# ===============
# atom-ph
# 0.992  Negative-Energy Perturbations in Circularly Cylindrical Equilibria within the Framework of Maxwell-Drift Kinetic Theory
# 0.990  On some Uncertainties in Evolutionary Synthesis Models
# 0.987  Closing the Universe by relaxing the cosmological constant
# 0.986  On the Origin of the Intensity Deficit in Neutron Compton Scattering
# 0.984  Precise Request Tracing and Performance Debugging for Multi-tier Services of Black Boxes
# 0.983  Synthesizing NMR analogues of Einstein-Podolsky-Rosen states using generalized Grover's algorithm
# 0.982  Hydrostatic pressure influence on dielectric permittivity of KH2PO4 and KD2PO4 in the piezoelectric resonance region
# 0.982  Mechanism of Laser Induced Compaction
# 0.981  SUSY signals at HERA in the no-scale flipped SU(5) supergravity model
# 0.980  Microphase separation in Pr0.67Ca0.33MnO3 by small angle neutron scattering
# ===============
# bayes-an
# 1.000  Comparison of Spearman's rho and Kendall's tau in Normal and Contaminated Normal Models
# 1.000  Evaluation of the Performance of the Markov Blanket Bayesian Classifier Algorithm
# 1.000  An extremal [72,36,16] binary code has no automorphism group containing Z2xZ4, Q_8, or Z_{10}
# 0.999  Machine learning prediction of cancer cell sensitivity to drugs based on genomic and chemical properties
# 0.999  Assigning confidence to inspiral gravitational wave candidates with Bayesian model selection
# 0.999  Conservation Laws and Formation of Singularities in Relativistic Theories of Extended Objects
# 0.999  Comment on ``Statistical Mechanics of a Nonlinear Model for DNA Denaturation''
# 0.999  Efficiently decoding strings from their shingles
# 0.999  Entropic Priors for Discrete Probabilistic Networks and for Mixtures of Gaussians Models
# 0.999  Periodic points of quasianalytic Hamiltonian billiards
# ===============
# chao-dyn
# 0.996  Exact Exponents of Supersonic Turbulence in Arbitrary Dimensions
# 0.993  Nonlinear Accelerator Problems via Wavelets: 6. Representations and Quasiclassics via FWT
# 0.987  General properties of propagation in chaotic systems
# 0.987  Expansion-modificaction systems: an explanation for long range correlations in DNA
# 0.985  Lindstedt series and Kolmogorov theorem
# 0.982  Chaotic principle: some applications to developed turbulence
# 0.982  A rigorous implementation of the Jeans--Landau--Teller approximation
# 0.972  Infinite-Dimensional Linear Dynamical Systems with Chaoticity
# 0.957  Spatiotemporal Dynamics of Mesoscopic Chaotic Systems
# 0.955  Fast Arnold's diffusion in isochronous systems
# ===============
# chem-ph
# 0.988  Identification of Amino Acid Sequences with Good Folding Properties in an Off-Lattice Model
# 0.987  A Criterion That Determines Fast Folding of Proteins: A Model Study
# 0.976  Optical absorption spectra of A6C60 and A6C70: Reduction of effective Coulomb interactions in Frenkel excitons
# 0.975  Doping Effects and Electronic States in C60-Polymers
# 0.975  Optical Absorption in Higher Fullerenes: Effects of Symmetry Reduction
# 0.974  Elastic anomaly of heavy fermion systems in a crystalline field
# 0.969  Optical absorption spectra of A6C60: Reduction of effective Coulombinteractions
# 0.965  Theory of an elastic anomaly in the heavy fermion system CeTe
# 0.958  The hydration free energy of water
# 0.957  Magic Numbers of Silicon Clusters
# ===============
# cmp-lg
# 0.997  Speech Recognition by Composition of Weighted Finite Automata
# 0.993  Efficient Analysis of Complex Diagrams using Constraint-Based Parsing
# 0.986  Finite State Transducers Approximating Hidden Markov Models
# 0.983  A Dynamic Approach to Rhythm in Language: Toward a Temporal Phonology
# 0.981  Tagging French -- comparing a statistical and a constraint-based method
# 0.975  Efficiency, Robustness, and Accuracy in Picky Chart Parsing
# 0.974  Phonetic Ambiguity : Approaches, Touchstones, Pitfalls and New Approaches
# 0.967  Ubiquitous Talker: Spoken Language Interaction with Real World Objects
# 0.965  Some Bibliographical References on Intonation and Intonational Meaning
# 0.965  GramCheck: A Grammar and Style Checker
# ===============
# comp-gas
# 0.994  Boundary conditions at a fluid - solid interface
# 0.994  A Vectorized Algorithm for Molecular Dynamics of Short Range Interacting Particles
# 0.994  Molecular Simulations of Dewetting
# 0.992  Computations on Nondeterministic Cellular Automata
# 0.991  A Lattice-Boltzmann method for the simulation of transport phenomena in charged colloids
# 0.990  Identification of Continuous-Time Dynamical Systems: Neural Network Based Algorithms and Parallel Implementation
# 0.990  Shock structure in a nine-velocity gas
# 0.990  Inverse Chapman-Enskog Derivation of the Thermohydrodynamic Lattice-BGK Model for the Ideal Gas
# 0.990  Cellular Automata Models for Diffusion of Innovations
# 0.990  Note on the dual BRST Symmetry in U(1) Gauge Theory
# ===============
# cond-mat
# 0.995  A new Proposal for a Quasielectron Trial Wavefunction for the FQHE on a Disk
# 0.984  SCALING AND INTERMITTENCY IN BURGERS' TURBULENCE
# 0.982  Parametric Spectral Correlations of Disordered Systems in the Fourier Domain
# 0.975  Anomalous Scaling Exponents of a White-Advected Passive Scalar
# 0.964  Capillary Wave Scattering from a Surfactant Domain
# 0.963  Magneto-Resistance in the Two-Channel Anderson Lattice
# 0.962  Clean and As-covered zinc-blende GaN (001) surfaces: Novel surface structures and surfactant behavior
# 0.957  Angular Forces Around Transition Metals in Biomolecules
# 0.946  The effects of the carrier interaction and electric fields on subband structures of selectively--doped semiconductor quantum wells
# 0.944  Multiple jumps and vacancy diffusion in a face-centered cubic metal
# ===============
# cond-mat.dis-nn
# 0.999  Comment on `Glassy Transition in a Disordered Model for the RNA Secondary Structure'
# 0.999  Glassy Dynamics of Simulated Polymer Melts: Coherent Scattering and Van Hove Functions Part II: Dynamics in the alpha-Relaxation Regime
# 0.998  Nonmonotonous Magnetic Field Dependence and Scaling of the Thermal Conductivity for Superconductors with Nodes of the Order Parameter
# 0.998  Second-Order Dynamics in the Collective Evolution of Coupled Maps and Automata
# 0.998  The $\pm J $ spin glass in Migdal-Kadanoff approximation
# 0.998  Broad histogram relation for the bond number and its applications
# 0.997  Universal crossing probabilities and incipient spanning clusters in directed percolation
# 0.997  Surface Magnetization and Critical Behavior of Aperiodic Ising Quantum Chains
# 0.997  Universal scaling functions for bond percolation on planar random and square lattices with multiple percolating clusters
# 0.997  Ripple and kink dynamics
# ===============
# cond-mat.mes-hall
# 1.000  Electronic mean free path in as-produced and purified single-wall carbon nanotubes
# 1.000  Energy relaxation due to magnetic impurities in mesoscopic wires: Logarithmic approach
# 1.000  Nano-mechanical magnetization reversal
# 1.000  Phonon-induced Exciton Dephasing in Quantum Dot Molecules
# 1.000  The role of electron scattering in magnetization relaxation in thin Ni$_{81}$Fe$_{19}$ films
# 1.000  Structural and electronic properties of the metal-metal intramolecular junctions of single-walled carbon nanotubes
# 1.000  Dissipative tunneling in structures with quantum dots and quantum molecules
# 1.000  Forces and conductances in a single-molecule bipyridine junction
# 1.000  Mean-field theory of magnetic properties of Mn$_x$III$_{1-x}$V semiconductors
# 1.000  Influence of Electron-electron Drag on Piezoresistance of n-Si
# ===============
# cond-mat.mtrl-sci
# 0.992  Optical transition in self-assembled InAs/GaAs quantum lens under high hydrostatic pressure
# 0.991  Coupled study by TEM/EELS and STM/STS of electronic properties of C- and CNx-nanotubes
# 0.991  Influence of Photoexcitation Depth on Luminescence Spectra of Bulk GaAs Single Crystals and Defect Structure Characterization
# 0.991  Long aging time thermal degradation of the ac conductivity and complex permittivity of conducting polypyrrole
# 0.991  Synthesis and characterization of HAp nanorods from a cationic surfactant template method
# 0.988  Surface doping in T6/ PDI-8CN2 Heterostructures investigated by transport and photoemission measurements
# 0.987  Thermodynamic stability of Fe/O solid solution at inner-core conditions
# 0.985  Wettability and 'petal effect' of GaAs native oxides
# 0.985  Tensorial mobilities for accurate solution of transport problems in models with diffuse interfaces
# 0.984  Modified exponential I(U) dependence and optical efficiency of AlGaAs SCH lasers in computer modeling with Synopsys TCAD
# ===============
# cond-mat.other
# 0.997  Energy Spectra of Few-Electron Quantum Dots
# 0.997  Self-consistent approach for the quantum confined Stark effect in shallow quantum wells
# 0.995  Coherent molecular solitons in Bose-Einstein condensates
# 0.995  A definitive number of atoms on demand: controlling the number of atoms in a-few-atom magneto-optical trap
# 0.993  Electronic viscosity in a quantum well: A test for the local density approximation
# 0.993  Simulation of finite state machines in a quantum computer
# 0.992  Positronium scattering by atoms and molecules at low energies
# 0.992  Dynamics of optically generated vortices in a one-component ultracold fermionic gases
# 0.991  Phase separation and vortex states in binary mixture of Bose-Einstein condensates
# 0.989  A Minimalist Model of Characteristic Earthquakes
# ===============
# cond-mat.quant-gas
# 1.000  Making, probing and understanding ultracold Fermi gases
# 1.000  Observation of Fermi Polarons in a Tunable Fermi Liquid of Ultracold Atoms
# 1.000  Superfluid-Insulator transition of two-species bosons with spin-orbit coupling
# 1.000  Stability of low-dimensional multicomponent Bose gases
# 1.000  Ultracold Fermi gases in the BEC-BCS crossover: a review from the Innsbruck perspective
# 1.000  A Bose-Einstein Condensate in a Uniform Light-induced Vector Potential
# 1.000  Obtaining phase diagram and thermodynamic quantities of bulk systems from the densities of trapped gases
# 1.000  Number Fluctuations and Energy Dissipation in Sodium Spinor Condensates
# 1.000  Observation of a 2D Bose-gas: from thermal to quasi-condensate to superfluid
# 1.000  Density profiles of polarized Fermi gases confined in harmonic traps
# ===============
# cond-mat.soft
# 0.999  Static and Dynamic Properties of a Viscous Silica Melt Molecular Dynamics Computer Simulations
# 0.999  On the role of thermal backbone fluctuations in myoglobin ligand gate dynamics
# 0.999  Amorphous Precursors of Crystallization during Spinodal Decomposition
# 0.998  Dynamics in a supercooled liquid of symmetric dumbbells: Reorientational hopping for small molecular elongations
# 0.998  Revisiting the slow dynamics of a silica melt using Monte Carlo simulations
# 0.998  Internal states of model isotropic granular packings. II. Compression and pressure cycles
# 0.998  On the dependence of the avalanche angle on the granular layer thickness
# 0.998  How Can Computer Simulations Contribute to Understand the Static Structure of Glasses?
# 0.998  The relaxation dynamics of a simple glass former confined in a pore
# 0.998  Dynamics of axial separation in long rotating drums
# ===============
# cond-mat.stat-mech
# 0.998  Core-shell structures in single flexible-semiflexible block copolymers: Finding the free energy minimum for the folding transition
# 0.997  General non-existence theorem for phase transitions in one-dimensional systems with short range interactions, and physical examples of such transitions
# 0.997  Self-Sustained Reaction Fronts in Porous Media
# 0.997  Gumbel distribution and current fluctuations in critical systems
# 0.996  Folding and unfolding kinetics of a single semiflexible polymer
# 0.996  The prolate-to-oblate shape transition of phospholipid vesicles in response to frequency variation of an AC electric field can be explained by the dielectric anisotropy of a phospholipid bilayer
# 0.995  Gel-state nucleation in multilamellar vesicles of dimyristoylphosphatidylcholine and its relation to the critical temperature: A lattice model and microcalorimetry
# 0.995  Adhesion of microcapsules
# 0.994  Stochastic Hysteresis and Resonance in a Kinetic Ising System
# 0.994  Substrate concentration dependence of the diffusion-controlled steady-state rate constant
# ===============
# cond-mat.str-el
# 0.999  Disappearance of antiferromagnetic spin excitations in over-doped La$_{2-x}$Sr$_{x}$CuO$_{4}$
# 0.999  Toroid Current States in Doped Antiferromagnetic Insulators
# 0.999  Structure and relevant dimension of the Heisenberg model and applications to spin rings
# 0.999  Interplay between the glassy transition and granular superconductivity in organic materials
# 0.999  Comments on gap anisotropy and nodal constant Fermi velocity in a superconductor, BSCCO
# 0.999  The origin of a$_{1g}$ and e$_g$' orderings in Na$_x$CoO$_2$
# 0.999  Multigap Superconductivity in Y$_2$C$_3$: A $^{13}$C-NMR Study
# 0.999  Critical charge dynamics of superconducting LSCO thin films probed by complex microwave spectroscopy: Anomalous changes of the universality class by hole doping
# 0.999  Temperature dependence of the upper critical field of an anisotropic singlet superconductivity in a square lattice tight-binding model in parallel magnetic fields
# 0.999  Phase segregation in NaxCoO2 for large Na contents
# ===============
# cond-mat.supr-con
# 1.000  Nesting between hole and electron pockets in Ba(Fe1-xCox)2As2 (x=0-0.3) observed with angle-resolved photoemission
# 1.000  Strong electron correlations in the normal state of FeSe0.42Te0.58
# 1.000  Real-space fluctuations of effective exchange integrals in high-Tc cuprates
# 1.000  Measurement and analysis of the Hall effect of A-Fe$_2$As$_2$ single crystals with A = Ba, Ca or Sr
# 1.000  Effects of phonon interaction on the pairing in the high-T$c$ superconductors
# 1.000  Charge dynamics of the Co-doped BaFe$_2$As$_2$
# 1.000  Physical properties of $A_x$Fe$_{2-y}$S$_2$ ($A$=K, Rb and Cs) single crystals
# 1.000  Pressure-induced high-Tc superconducting phase in FeSe: correlation between anion height and Tc
# 1.000  Fermi liquid state and enhanced electron correlations in the new iron pnictide CaFe$_4$As$_3$
# 1.000  Anisotropic thermal expansion of AEFe2As2 (AE = Ba, Sr, Ca) single crystals
# ===============
# cs.AI
# 0.991  Incorporating Causal Prior Knowledge as Path-Constraints in Bayesian Networks and Maximal Ancestral Graphs
# 0.978  Using Counterfactuals in Knowledge-Based Programming
# 0.974  Verification, Validation and Integrity of Distributed and Interchanged Rule Based Policies and Contracts in the Semantic Web
# 0.972  Wikipedia Vandalism Detection Through Machine Learning: Feature Review and New Proposals: Lab Report for PAN at CLEF 2010
# 0.962  Genetic Algorithms for Extension Search in Default Logic
# 0.959  Computing with Logic as Operator Elimination: The ToyElim System
# 0.958  The SeaLion has Landed: An IDE for Answer-Set Programming---Preliminary Report
# 0.940  An example illustrating the imprecision of the efficient approach for diagnosis of Petri nets via integer linear programming
# 0.938  ALARMS: Alerting and Reasoning Management System for Next Generation Aircraft Hazards
# 0.938  An ontology-based approach to relax traffic regulation for autonomous vehicle assistance
# ===============
# cs.AR
# 0.999  Predictability of Fixed-Job Priority Schedulers on Heterogeneous Multiprocessor Real-Time Systems
# 0.999  FPGA-based Controller for a Mobile Robot
# 0.999  Composition and Inversion of Schema Mappings
# 0.999  Design of Optimal Regulators
# 0.999  Providing Virtual Execution Environments: A Twofold Illustration
# 0.999  Evaluating Trust in Grid Certificates
# 0.999  Platform-to-platform sample transfer, distribution, dilution, and dosing via electrothermal vaporization and electrostatic deposition
# 0.999  The Structure of the Bern-Kosower Integrand for the N-Gluon Amplitude
# 0.999  Robust Watermarking in Multiresolution Walsh-Hadamard Transform
# 0.997  Cluster Crystals in Confinement
# ===============
# cs.CC
# 1.000  Using CSP To Improve Deterministic 3-SAT
# 1.000  The Multiplicative Quantum Adversary
# 1.000  A Time-Efficient Output-Sensitive Quantum Algorithm for Boolean Matrix Multiplication
# 1.000  A learning graph based quantum query algorithm for finding constant-size subgraphs
# 1.000  Quantum Property Testing of Group Solvability
# 1.000  Lower Bounds on Query Complexity for Testing Bounded-Degree CSPs
# 1.000  Exact quantum query complexity for total Boolean functions
# 1.000  Quantum Algorithm for Commutativity Testing of a Matrix Set
# 1.000  Quantum lower bounds for the collision and the element distinctness problems
# 1.000  Optimal quantum adversary lower bounds for ordered search
# ===============
# cs.CE
# 0.992  GUBS, a Behavior-based Language for Open System Dedicated to Synthetic Biology
# 0.973  Revisiting Matrix Product on Master-Worker Platforms
# 0.967  Electricity Demand and Energy Consumption Management System
# 0.965  An Effect of Spatial Filtering in Visualization of Coronary Arteries Imaging
# 0.965  Computer Modelling of 3D Geological Surface
# 0.960  The specifications making in complex CAD-system of renovation of the enterprises on the basis of modules in the drawing and electronic catalogues
# 0.960  The modular technology of development of the CAD expansions: profiles of outside networks of water supply and water drain
# 0.960  Environment of development of the programs of parametric creating of the drawings in CAD-system of renovation of the enterprises
# 0.960  Modular technology of developing of the problem-oriented extensions of a CAD system of reconstruction of the plant
# 0.960  The modular technology of development of the CAD expansions: protection of the buildings from the lightning
# ===============
# cs.CG
# 0.999  Mergeable Dictionaries
# 0.999  Multiple source, single sink maximum flow in a planar graph
# 0.999  A Durable Flash Memory Search Tree
# 0.999  Efficient K-Nearest Neighbor Join Algorithms for High Dimensional Sparse Data
# 0.999  How to meet asynchronously (almost) everywhere
# 0.999  Demand-Supply Optimization with Risk Management for a Multi-Connection Water Reservoir Network
# 0.999  Document Clustering with K-tree
# 0.999  Multiple-Source Multiple-Sink Maximum Flow in Directed Planar Graphs in $O(n^{1.5} \log n)$ Time
# 0.999  Geometric Thickness of Complete Graphs
# 0.999  A Streaming Approximation Algorithm for Klee's Measure Problem
# ===============
# cs.CL
# 0.991  'I don't believe in word senses'
# 0.989  Evaluating a Focus-Based Approach to Anaphora Resolution
# 0.989  Co-evolution of Language and of the Language Acquisition Device
# 0.989  Never Look Back: An Alternative to Centering
# 0.989  Tailored Patient Information: Some Issues and Questions
# 0.989  Text Segmentation Using Exponential Models
# 0.989  Name Searching and Information Retrieval
# 0.989  Machine Learning of User Profiles: Representational Issues
# 0.989  Similarity-Based Methods For Word Sense Disambiguation
# 0.989  A Czech Morphological Lexicon
# ===============
# cs.CR
# 0.998  Power-Efficient Direct-Voting Assurance for Data Fusion in Wireless Sensor Networks
# 0.998  Verifiable quantum oblivious transfer protocol based on entangled states
# 0.998  Memory Retrieval in the B-Matrix Neural Network
# 0.998  A Novel Approach to Fully Private and Secure Auction: A Sealed Bid Knapsack Auction
# 0.997  A secure key transfer protocol for group communication
# 0.997  A Hash based Approach for Secure Keyless Steganography in Lossless RGB Images
# 0.997  Extending WS-Security to Implement Security Protocols for Web Services
# 0.997  Impact of Rushing attack on Multicast in Mobile Ad Hoc Network
# 0.997  On graph coloring check-digit method
# 0.997  SafeMPI - Extending MPI for Byzantine Error Detection on Parallel Clusters
# ===============
# cs.CV
# 0.995  Adaptive grids as parametrized scale-free networks
# 0.994  Radiation-cooled Dew Water Condensers Studied by Computational Fluid Dynamic (CFD)
# 0.994  Reaction-diffusion dynamics: confrontation between theory and experiment in a microfluidic reactor
# 0.994  Dynamic Point-Formation in Dielectric Fluids
# 0.993  Analytical model to predict the effect of a finite impedance surface on the propagation properties of a 2D Sonic Crystal
# 0.993  Contemporary Approach for Simulation and Computation of Fluid Flows in Centrifugal Hydromachines
# 0.993  Streamwise evolution of the entrainment in a steady two-dimensional bluff-body wake
# 0.993  Stretching of polymers in a random three-dimensional flow
# 0.991  Fusion of Multiple Matchers using SVM for Offline Signature Identification
# 0.991  Feature Level Clustering of Large Biometric Database
# ===============
# cs.CY
# 0.997  Catroid: A Mobile Visual Programming System for Children
# 0.976  Introducing OPTO : Portal for Optical Communities in Indonesia
# 0.970  Protecting Spreadsheets Against Fraud
# 0.968  HTTP Cookies: Standards, Privacy, and Politics
# 0.964  EGovernment Stage Model: Evaluating the Rate of Web Development Progress of Government Websites in Saudi Arabia
# 0.964  Government Initiatives: The Missing Key for E-commerce Growth in KSA
# 0.964  A Conceptual Framework for the Promotion of Trusted Online Retailing Environment in Saudi Arabia
# 0.964  The Effects of Website Quality on Adoption of E-Government Service: AnEmpirical Study Applying UTAUT Model Using SEM
# 0.964  Factors influencing the decision of Saudi consumers to purchase form online retailers: Quantitative Analysis
# 0.960  Success Factors Contributing to eGovernment Adoption in Saudi Arabia: G2C approach
# ===============
# cs.DB
# 1.000  A Variant of Earley Parsing
# 0.999  An Effective Clustering Approach to Web Query Log Anonymization
# 0.999  An Improved Approach to High Level Privacy Preserving Itemset Mining
# 0.999  Scalable Continual Top-k Keyword Search in Relational Databases
# 0.999  Using Tree Automata and Regular Expressions to Manipulate Hierarchically Structured Data
# 0.999  Indexed Languages and Unification Grammars
# 0.998  Fast Algorithms for Mining Interesting Frequent Itemsets without Minimum Support
# 0.998  Ramp: Fast Frequent Itemset Mining with Efficient Bit-Vector Projection Technique
# 0.995  Scalable Probabilistic Similarity Ranking in Uncertain Databases (Technical Report)
# 0.994  Provenance as Dependency Analysis
# ===============
# cs.DC
# 0.996  Counter Attack on Byzantine Generals: Parameterized Model Checking of Fault-tolerant Distributed Algorithms
# 0.995  Research Challenges for Enterprise Cloud Computing
# 0.992  A Statistical Approach to Performance Monitoring in Soft Real-Time Distributed Systems
# 0.992  Sample-Align-D: A High Performance Multiple Sequence Alignment System using Phylogenetic Sampling and Domain Decomposition
# 0.988  Multi-Threading And Message Communication In Qu-Prolog
# 0.984  On reducing the complexity of matrix clocks
# 0.971  FATAL+: A Self-Stabilizing Byzantine Fault-tolerant Clocking Scheme for SoCs
# 0.971  A Simple Multi-Processor Computer Based on Subleq
# 0.968  Intelligent strategies for DAG scheduling optimization in Grid environments
# 0.967  Jeeva: Enterprise Grid-enabled Web Portal for Protein Secondary Structure Prediction
# ===============
# cs.DL
# 0.999  Using Web Page Titles to Rediscover Lost Web Pages
# 0.999  Preserving Peer Replicas By Rate-Limited Sampled Voting in LOCKSS
# 0.999  Is This a Good Title?
# 0.999  Subject Access through Community Partnerships: A Case Study
# 0.998  Better Than Their Reputation? On the Reliability of Relevance Assessments with Students
# 0.998  Implications of Inter-Rater Agreement on a Student Information Retrieval Evaluation
# 0.998  Design, fabrication and measurement of the first rounded damped detuned accelerator structure (RDDS1)
# 0.998  Manifold Damping Of Wakefields In High Phase Advance Linacs For The NLC
# 0.998  Manifold Damping of Transverse Wakefields in High Phase Advance Traveling Wave Structures and Local Damping of Dipole Wakefields in Standing Wave Accelerators
# 0.998  Conquering the rating bound problem in neighborhood-based collaborative filtering: a function recovery approach
# ===============
# cs.DM
# 0.996  A new edge selection heuristic for computing the Tutte polynomial of an undirected graph
# 0.981  On Ordinal Covering of Proposals Using Balanced Incomplete Block Designs
# 0.981  Bipartite graphs with a perfect matching and digraphs
# 0.978  Packing six T-joins in plane graphs
# 0.975  Circular colorings, orientations, and weighted digraphs
# 0.974  Counting perfect matchings of cubic graphs in the geometric dual
# 0.969  Nordhaus-Guddam Type Relations of Three Graph Coloring Parameters
# 0.964  The structure of graphs with a vital linkage of order 2
# 0.964  Hospital Acquired Infections: Advantages of a Computerized Surveillance
# 0.963  Minor-minimal planar graphs of even branch-width
# ===============
# cs.DS
# 1.000  On Approximating Graph Bipartization via Node Deletion
# 0.999  A Proof Checking View of Parameterized Complexity
# 0.999  Spectral Algorithms for Unique Games
# 0.999  Understanding Space in Proof Complexity: Separations and Trade-offs via Substitutions
# 0.999  Structure from Local Optima: Learning Subspace Juntas via Higher Order PCA
# 0.999  Single Parameter Combinatorial Auctions with Partially Public Valuations
# 0.999  An External Description for MIMO Systems Sampled in an Aperiodic Way
# 0.999  Controlled non uniform random generation of decomposable structures
# 0.999  Modelling Nonlinear Sequence Generators in terms of Linear Cellular Automata
# 0.999  Approximate Distance Oracles with Improved Preprocessing Time
# ===============
# cs.ET
# 0.999  Building Toffoli Network for Reversible Logic Synthesis Based on Swapping Bit Strings
# 0.999  Synthesis of Fault Tolerant Reversible Logic Circuits
# 0.999  Joint probability density function modeling of velocity and scalar in turbulence with unstructured grids
# 0.999  Sorting Network for Reversible Logic Synthesis
# 0.998  Experimental Implementation of the Deutsch-Jozsa Algorithm for Three-Qubit Functions using Pure Coherent Molecular Superpositions
# 0.998  BSSSN: Bit String Swapping Sorting Network for Reversible Logic Synthesis
# 0.998  Quantum associative memory with improved distributed queries
# 0.998  Synthesis of Reversible Functions Beyond Gate Count and Quantum Cost
# 0.997  Digital Switching in the Quantum Domain
# 0.996  Drop-coated Titanium Dioxide Memristors
# ===============
# cs.FL
# 0.999  Computing Optimal Coverability Costs in Priced Timed Petri Nets
# 0.999  Taming Past LTL and Flat Counter Systems
# 0.999  Reachability of Communicating Timed Processes
# 0.999  Model Checking Parse Trees
# 0.999  Finding the growth rate of a regular language in polynomial time
# 0.999  Avoiding Abelian powers in binary words with bounded Abelian complexity
# 0.999  Some characterizations of Sturmian words in terms of the lexicographic order
# 0.999  Efficient Parallel Path Checking for Linear-Time Temporal Logic With Past and Bounds
# 0.999  Highly Undecidable Problems For Infinite Computations
# 0.999  Decision Problems for Petri Nets with Names
# ===============
# cs.GL
# 0.999  Scheduling with Fuzzy Methods
# 0.997  Trustworthy 100-Year Digital Objects: Durable Encoding for When It's Too Late to Ask
# 0.997  Rippling patterns in aggregates of myxobacteria arise from cell-cell collisions
# 0.997  Near Optimal Routing for Small-World Networks with Augmented Local Awareness
# 0.996  Hybrid Elections Broaden Complexity-Theoretic Resistance to Control
# 0.996  Is Neural Network a Reliable Forecaster on Earth? A MARS Query!
# 0.995  Playful, streamlike computation
# 0.994  Ground Canonicity
# 0.994  One-way Hash Function Based on Neural Network
# 0.993  A T Step Ahead Optimal Target Detection Algorithm for a Multi Sensor Surveillance System
# ===============
# cs.GR
# 0.995  Aplicacion Grafica para el estudio de un Modelo de Celda Electrolitica usando Tecnicas de Visualizacion de Campos Vectoriales
# 0.992  Text/Graphics Separation for Business Card Images for Mobile Devices
# 0.992  Learning a Representation of a Believable Virtual Character's Environment with an Imitation Algorithm
# 0.975  Pipelining the Fast Multipole Method over a Runtime System
# 0.972  PROGRAPE-1: A Programmable, Multi-Purpose Computer for Many-Body Simulations
# 0.968  A GPU implementation of the Simulated Annealing Heuristic for the Quadratic Assignment Problem
# 0.961  Critical behavior of ferromagnetic spin models with aperiodic exchange interactions
# 0.959  Speculative Parallel Evaluation Of Classification Trees On GPGPU Compute Engines
# 0.958  A basic gesture and motion format for virtual reality multisensory applications
# 0.958  Visualization of Collaborative Data
# ===============
# cs.GT
# 1.000  Processor Allocation for Optimistic Parallelization of Irregular Programs
# 0.999  On Using Seeders for P2P Live Streaming
# 0.999  Qualitative Analysis of Partially-observable Markov Decision Processes
# 0.999  Nash-equilibria and N-fold integer programming
# 0.999  Resource Pricing In A Dynamic Multi-Commodity Market For Computational Resources
# 0.999  An Energy-efficient Clock Synchronization Protocol for Wireless Sensor Networks
# 0.999  Distributed Spectrum Access with Spatial Reuse
# 0.999  The generalized work function algorithm is competitive for the generalized 2-server problem
# 0.999  Matroid intersection, base packing and base covering for infinite matroids
# 0.998  Uncertain Congestion Games with Assorted Human Agent Populations
# ===============
# cs.HC
# 0.991  The Role of Spreadsheets in the Allied Irish Bank / Allfirst Currency Trading Fraud
# 0.991  Exploring Human Factors in Spreadsheet Development
# 0.991  What we understand is what we get: Assessment in Spreadsheets
# 0.990  Revisiting the Panko-Halverson Taxonomy of Spreadsheet Errors
# 0.990  A Practical Approach to Managing Spreadsheet Risk in a Global Business
# 0.990  Transforming Critical Spreadsheets into Web Applications at Zurich Financial
# 0.990  Archiving: The Overlooked Spreadsheet Risk
# 0.990  Applying the CobiT Control Framework to Spreadsheet Developments
# 0.990  Comparison of Spreadsheets with other Development Tools (limitations, solutions, workarounds and alternatives)
# 0.990  Spreadsheet Risk Management in Organisations
# ===============
# cs.IR
# 0.999  NLP-SIR: A Natural Language Approach for Spreadsheet Information Retrieval
# 0.999  Automated Query Learning with Wikipedia and Genetic Programming
# 0.998  Attempto - From Specifications in Controlled Natural Language towards Executable Specifications
# 0.998  Fine-Grained Word Sense Disambiguation Based on Parallel Corpora, Word Alignment, Word Clustering and Aligned Wordnets
# 0.998  A Discourse-based Approach in Text-based Machine Translation
# 0.998  Building a resource for studying translation shifts
# 0.998  A toolkit for a generative lexicon
# 0.998  International Standard for a Linguistic Annotation Framework
# 0.998  Change of word types to word tokens ratio in the course of translation (based on Russian translations of K. Vonnegut novels)
# 0.998  An Automated Evaluation Metric for Chinese Text Entry
# ===============
# cs.IT
# 0.999  Feedback control logic synthesis for non safe Petri nets
# 0.995  Energy Minimization for the Half-Duplex Relay Channel with Decode-Forward Relaying
# 0.994  Diversity Analysis of Bit-Interleaved Coded Multiple Beamforming
# 0.993  Blind Adaptive Subcarrier Combining Technique for MC-CDMA Receiver in Mobile Rayleigh Channel
# 0.992  Reduced-Rank Adaptive Filtering Based on Joint Iterative Optimization of Adaptive Filters
# 0.989  Analysis of Energy Efficiency in Fading Channels under QoS Constraints
# 0.988  Repeated Root Constacyclic Codes of Length $mp^s$ over $\mathbb{F}_{p^r}+u \mathbb{F}_{p^r}+...+ u^{e-1}\mathbb{F}_{p^r}$
# 0.987  On the Cramer-Rao Lower Bound for Spatial Correlation Matrices of Doubly Selective Fading Channels for MIMO OFDM Systems
# 0.986  Coding With Action-dependent Side Information and Additional Reconstruction Requirements
# 0.985  Remarks on the Criteria of Constructing MIMO-MAC DMT Optimal Codes
# ===============
# cs.LG
# 0.994  Fuzzy soft rough K-Means clustering approach for gene expression data
# 0.990  Convergence and Loss Bounds for Bayesian Sequence Prediction
# 0.989  Active Learning for Matching Problems
# 0.987  Developing courses with HoloRena, a framework for scenario- and game based e-learning environments
# 0.986  Toward a Classification of Finite Partial-Monitoring Games
# 0.985  Analysing the behaviour of robot teams through relational sequential pattern mining
# 0.981  Ensembles of Radial Basis Function Networks for Spectroscopic Detection of Cervical Pre-Cancer
# 0.973  Uniform Approximation and Bracketing Properties of VC classes
# 0.972  A Formalization of the Turing Test
# 0.971  An Online Learning-based Framework for Tracking
# ===============
# cs.LO
# 0.995  Required Behavior of Sequence Diagrams: Semantics and Conformance
# 0.993  Tableau-based decision procedure for the multi-agent epistemic logic with all coalitional operators for common and distributed knowledge
# 0.993  A Domain-Specific Language for Incremental and Modular Design of Large-Scale Verifiably-Safe Flow Networks (Preliminary Report)
# 0.988  The Maximal Subword Complexity of Quasiperiodic Infinite Words
# 0.988  Proceedings Second Workshop on Logics for Component Configuration
# 0.986  Multiple verification in computational modeling of bone pathologies
# 0.985  Representing a P-complete problem by small trellis automata
# 0.983  Conditional Chow-Liu Tree Structures for Modeling Discrete-Valued Vector Time Series
# 0.982  Refinement Types as Higher Order Dependency Pairs
# 0.982  A Reduction-Preserving Completion for Proving Confluence of Non-Terminating Term Rewriting Systems
# ===============
# cs.MA
# 0.996  Multi-Issue Negotiation with Deadlines
# 0.996  Efficiency-Risk Tradeoffs in Dynamic Oligopoly Markets - with application to electricity markets
# 0.995  An adaptive routing strategy for packet delivery in complex networks
# 0.994  Delay Stability Regions of the Max-Weight Policy under Heavy-Tailed Traffic
# 0.992  Linear Consensus Algorithms Based on Balanced Asymmetric Chains
# 0.990  Decomposition of analytic measures on groups and measure spaces
# 0.990  Greedy Gossip with Eavesdropping
# 0.983  On the Design of Agent-Based Systems using UML and Extensions
# 0.982  Learning Nested Agent Models in an Information Economy
# 0.979  Leader Election for Anonymous Asynchronous Agents in Arbitrary Networks
# ===============
# cs.MM
# 0.990  Optimized reversible BCD adder using new reversible logic gates
# 0.988  A Performance Analysis of HICCUPS - a Steganographic System for WLAN
# 0.987  An Efficient Watermarking Algorithm to Improve Payload and Robustness without Affecting Image Perceptual Quality
# 0.986  Improving Effectiveness Of ELearning In Maintenance Using Interactive 3D
# 0.985  Supervised Learning of Digital image restoration based on Quantization Nearest Neighbor algorithm
# 0.978  Comparative Evaluation and Analysis of IAX and RSW
# 0.977  Adaptive Neuro-Fuzzy Extended Kalman Filtering for Robot Localization
# 0.976  Designing a Truly Integrated (Onsite and Online) Conference: Concept, Processes, Solutions
# 0.975  Digital Image Watermarking for Arbitrarily Shaped Objects Based On SA-DWT
# 0.975  A Novel Watermarking Scheme for Detecting and Recovering Distortions in Database Tables
# ===============
# cs.MS
# 0.998  Recursive Schur Decomposition
# 0.998  Computational complexity and memory usage for multi-frontal direct solvers in structured mesh finite elements
# 0.998  Unstructured Geometric Multigrid in Two and Three Dimensions on Complex and Graded Meshes
# 0.998  Flexible Complementarity Solvers for Large-Scale Applications
# 0.998  A direct solver with reutilization of previously-computed LU factorizations for h-adaptive finite element grids with point singularities
# 0.998  Managing Communication Latency-Hiding at Runtime for Parallel Programming Languages and Libraries
# 0.997  Matrix Stretching for Linear Equations
# 0.996  Solving Dense Generalized Eigenproblems on Multi-threaded Architectures
# 0.995  A stabilized Nitsche overlapping mesh method for the Stokes problem
# 0.992  A Massively Parallel Algebraic Multigrid Preconditioner based on Aggregation for Elliptic Problems with Heterogeneous Coefficients
# ===============
# cs.NA
# 0.997  O adsorption and incipient oxidation of the Mg(0001) surface
# 0.994  Automatic finite elements mesh generation from planar contours of the brain: an image driven 'blobby' approach
# 0.991  Iterative Residual Rescaling: An Analysis and Generalization of LSI
# 0.989  Oversampling for the Multiscale Finite Element Method
# 0.987  A cooperative conjugate gradient method for linear systems permitting multithread implementation of low complexity
# 0.986  Numerical Solution of the Tomography Problem in Domains with Obstacles
# 0.986  Prunnig Algorithm of Generation a Minimal Set of Rule Reducts Based on Rough Set Theory
# 0.985  A Direct Sampling Method for Inverse Electromagnetic Medium Scattering
# 0.984  A fast and robust patient specific Finite Element mesh registration technique: application to 60 clinical cases
# 0.983  Nimble@ITCEcnoGrid: A Grid in Research Domain for Weather Forecasting
# ===============
# cs.NE
# 1.000  Assembly and Disassembly Planning by using Fuzzy Logic & Genetic Algorithms
# 1.000  Internet Radio: A New Engine for Content Diversity?
# 1.000  RESID: A Practical Stochastic Model for Software Reliability
# 1.000  Search-based software test data generation using evolutionary computation
# 0.999  Self-Adaptive Surrogate-Assisted Covariance Matrix Adaptation Evolution Strategy
# 0.997  An Indirect Genetic Algorithm for a Nurse Scheduling Problem
# 0.997  AntNet: Distributed Stigmergetic Control for Communications Networks
# 0.997  Using Intelligent Agents to Understand Management Practices and Retail Productivity
# 0.997  An Estimation of Distribution Algorithm for Nurse Scheduling
# 0.997  Enhanced Direct and Indirect Genetic Algorithm Approaches for a Mall Layout and Tenant Selection Problem
# ===============
# cs.NI
# 0.994  Participatory Privacy: Enabling Privacy in Participatory Sensing
# 0.993  A Frame Rate Optimization Framework For Improving Continuity In Video Streaming
# 0.993  Improving TCP Performance over Wireless Network with Frequent Disconnections
# 0.993  JiTS: Just-in-Time Scheduling for Real-Time Sensor Data Dissemination
# 0.985  Performance Evaluation of Packet-to-Cell Segmentation Schemes in Input Buffered Packet Switches
# 0.983  Evaluation of Lifetime Bounds of Wireless Sensor Networks
# 0.983  Identification of efficient peers in P2P computing system for real time applications
# 0.982  Priority based Interface Selection for Overlaying Heterogeneous Networks
# 0.981  A Contribution to Secure the Routing Protocol 'Greedy Perimeter Stateless Routing' Using a Symmetric Signature-Based AES and MD5 Hash
# 0.979  The Distributed Computing Model Based on The Capabilities of The Internet
# ===============
# cs.OH
# 0.998  Computational Solutions for Today's Navy
# 0.998  On-Line Tests
# 0.998  Une approche par les mod\`eles pour le suivi de l'activit\'e de construction d'un b\^atiment. Bat'iViews : une interface multi-vues orient\'ee gestion de chantier
# 0.998  Enterprise Content Management: Theory and Engineering for Entire Lifecycle Support
# ...
# 0.974  Towards quantitative measures in applied ontology
# 0.964  Supporting information for: New methods for analyzing serological data with applications to influenza surveillance
# 0.963  Inter-layer slide and stress relaxation in a bilayer fluid membrane in the patch-clamp setting
# 0.939  Strongly nonlinear waves in capillary electrophoresis
# 0.926  Oligopeptides' frequencies in the classification of proteins' primary structures
# 0.915  Homogeneity tests for Michaelis-Menten curves with application to fluorescence resonance energy transfer data
# 0.840  RAId DbS: A Mass-Spectrometry Based Peptide Identification Web Server with Knowledge Integration
# 0.808  Sound and Image Processing with Optical Biocomputers
# ===============
# q-bio.SC
# 0.999  Dynamics of Molecular Motors in Reversible Burnt-Bridge Models
# 0.999  Presence of pKa Perturbations Among Homeodomain Residues Facilitates DNA Binding
# 0.999  Dynamic concentration of motors in microtubule arrays
# 0.999  Dynamics of unbinding of polymers in a random medium
# 0.999  RNA secondary structure formation: a solvable model of heteropolymer folding
# 0.999  How non-Gibbsianness helps a metastable Morita minimizer to provide a stable free energy
# 0.999  Reaction Diffusion and Ballistic Annihilation Near an Impenetrable Boundary
# 0.999  First-order rigidity transition on Bethe Lattices
# 0.999  Elastically coupled molecular motors
# 0.999  Scaling laws of creep rupture of fiber bundles
# ===============
# q-bio.TO
# 0.996  Velocity distribution of neutral particles ejected from biological material under ultra short laser radiation
# 0.989  Large Diffuse Halos in Time-Dependent Space-Charge Potentials with Colored Noise
# 0.983  A Simple Model of Pupal Water Loss in Glossina
# 0.980  Localised IR spectroscopy of hemoglobin
# 0.980  Dynamic Properties of Human Bronchial Airway Tissues
# 0.971  Smart Spectrometer for Distributed Fuzzy Control
# 0.969  Potential Phytoextraction with in-vitro regenerated plantlets of Brassica juncea (L.) Czern. in presence of CdCl$_2$: Cadmium accumulation and physiological parameter measurement
# 0.963  To a Problem of Not Increasing Dynamic Compliance at Asthma Patients with Ventilating Disorders after Berotec Inhalation
# 0.946  Nimesulide limits kainate-induced oxidative damage in the rat hippocampus
# 0.946  Regional distribution of the prostaglandin E2 receptor EP1 in the rat brain: accumulation in Purkinje cells of the cerebellum
# ===============
# q-fin.CP
# 0.999  Yield to maturity modelling and a Monte Carlo Technique for pricing Derivatives on Constant Maturity Treasury (CMT) and Derivatives on forward Bonds
# 0.997  Fast Computation of the Expected Loss of a Loan Portfolio Tranche in the Gaussian Factor Model: Using Hermite Expansions for Higher Accuracy
# 0.991  Binomial Tree Model for Convertible Bond Pricing within Equity to Credit Risk Framework
# 0.989  An Efficient Method For Multichannel Wireless Mesh Networks With Pulse Coupled Neural Network
# 0.977  Recovering a time-homogeneous stock price process from perpetual option prices
# 0.974  Valuation Bound of Tranche Options
# 0.973  Exact Pricing Asymptotics of Investment-Grade Tranches of Synthetic CDO's Part I: A Large Homogeneous Pool
# 0.964  Early exercise boundary for American type of floating strike Asian option and its numerical approximation
# 0.958  Parity Doublets from a Relativistic Quark Model
# 0.932  Bounds on Stock Price probability distributions in Local-Stochastic Volatility models
# ===============
# q-fin.GN
# 0.996  Random trading market: Drawbacks and a realistic modification
# 0.994  Relationship between inflation, unemployment and labor force change rate in France: cointegration test
# 0.993  The distribution of landed property
# 0.993  Networks between Professionals and Society: A Model for Protein Dependency
# 0.992  T-Duality and Mixed Branes
# 0.991  A Note on the $c=1$ Barrier in Liouville Theory
# 0.991  Stick-slip statistics for two fractal surfaces: A model for earthquakes
# 0.989  Multicritical Behavior of $c=1$ Matrix Model
# 0.989  Percolation in deposits for competitive models in (1+1)-dimensions
# 0.988  Inhomogeneous and self-organised temperature in Schelling-Ising model
# ===============
# q-fin.PM
# 0.998  Rentes en cours de service : un nouveau crit\`ere d'allocation d'actif
# 0.997  On the Generating Functional of the special case of S-Stopped Branching Processes
# 0.997  Two New Entropy Estimators for Testing Exponentiality with Type-II Censored Data
# 0.997  A characterization of D-norms and their generators based on the family of spectral functions
# 0.997  Utility Indifference Pricing: A Time Consistent Approach
# 0.997  Block Tensor Unfoldings
# 0.996  A simple method for decision making in robocup soccer simulation 3d environment
# 0.996  Constructions of Grassmannian Simplices
# 0.996  Maximum principles for boundary-degenerate second-order linear elliptic differential operators
# 0.995  Pricing Variable Annuity Contracts with High-Water Mark Feature
# ===============
# q-fin.PR
# 0.999  Jump-Diffusion Risk-Sensitive Asset Management II: Jump-Diffusion Factor Model
# 0.999  A simple discretization scheme for nonnegative diffusion processes, with applications to option pricing
# 0.999  Efficient simulation and calibration of general HJM models by splitting schemes
# 0.999  Relativistic field-theoretical formulation of the three-dimensional equations for the three fermion system
# 0.998  On affine interest rate models
# 0.998  Optimal decision under ambiguity for diffusion processes
# 0.998  An efficient solver for problems of scattering by bodies of revolution
# 0.997  A method of moments approach to pricing double barrier contracts driven by a general class of jump diffusions
# 0.997  Error bounds for small jumps of L\'evy processes
# 0.997  Numerical methods for optimal insurance demand under marked point processes shocks
# ===============
# q-fin.RM
# 0.995  Predictability of PV power grid performance on insular sites without weather stations: use of artificial neural networks
# 0.979  On Cellular Automata Models of Single Lane Traffic
# 0.978  Central Counterparty Risk
# 0.971  Asset-asset interactions and clustering in financial markets
# 0.957  A Model for Counterparty Risk with Geometric Attenuation Effect and the Valuation of CDS
# 0.945  A Chaos-based Image Encryption Scheme using Chaotic Coupled Map Lattices
# 0.943  Study on optimal timing of mark-to-market for contingent credit risk control
# 0.938  Evaluating the Precision of Estimators of Quantile-Based Risk Measures
# 0.938  Organizational adaptation to Complexity: A study of the South African Insurance Market as a Complex Adaptive System through Statistical Risk Analysis
# 0.932  Stage Staffing Scheme for Copyright Protection in Multimedia
# ===============
# q-fin.ST
# 0.999  Activity spectrum from waiting-time distribution
# 0.998  Dual Multifractal Spectra
# 0.998  Why Financial Markets Will Remain Marginally Inefficient?
# 0.998  Financial Networks in the Korean Stock Exchange Market
# 0.998  The Grammar of Sense: Is word-sense tagging much more than part-of-speech tagging?
# 0.998  Mechanism of antifreeze proteins action, based on Hierarchic theory of water and new ''clusterphilic'' interaction
# 0.997  Copolymer Networks and Stars: Scaling Exponents
# 0.997  Tagging French Without Lexical Probabilities -- Combining Linguistic Knowledge And Statistical Learning
# 0.997  Surface Scaling Analysis of a Frustrated Spring-network Model for Surfactant-templated Hydrogels
# 0.997  Multiscale Decomposition for Vlasov-Poisson Equations
# ===============
# q-fin.TR
# 0.999  Wetting phenomena in bcc binary alloys
# 0.998  Short-term equity dynamics and endogenous market fluctuations
# 0.998  Fixed points, stability and intermittency in a shell model for advection of passive scalars
# 0.998  Second-Order Type Isomorphisms Through Game Semantics
# 0.998  Heterogeneous volatility cascade in financial markets
# 0.998  Diffusion with random distribution of static traps
# 0.998  Common Scaling Patterns in Intertrade Times of U. S. Stocks
# 0.997  An empirical behavioral model of liquidity and volatility
# 0.997  Numerical analysis of the Minimal and Two-Liquid models of the Market Microstructure
# 0.997  Dynamical Mechanisms in Multi-agent Systems: Minority Games
# ===============
# quant-ph
# 1.000  Harmonic generation in ring-shaped molecules
# 1.000  Pulse-to-pulse Beam Modulation and Event-based Beam Feedback System at KEKB Linac
# 1.000  Dynamics of interacting clusters and dielectric response of relaxor ferroelectrics
# 1.000  Incorporating Integrity Constraints in Uncertain Databases
# 1.000  SUSY at High Energy $e\gamma$ and $\gamma\gamma$ Colliders
# 1.000  Bell's Inequalities and Algebraic Structure
# 1.000  Comment on Solution of the Relativistic Dirac-Morse Problem
# 1.000  Theory of optical spectra of polar quantum wells: Temperature effects
# 1.000  Conductivity of interacting spinless fermion systems via the high dimensional approach
# 1.000  Charmed hadron physics in quenched anisotropic lattice QCD
# ===============
# solv-int
# 0.992  Subcritical catalytic branching random walk with finite or infinite variance of offspring number
# 0.991  A Hopf bifurcation with a strong incommensurate frequency response in quantum wells
# 0.991  Dualities of the entropy bound
# 0.988  Existence and homogenization of the Rayleigh-B\'enard problem
# 0.988  Multifractality of Brownian motion near absorbing polymers
# 0.985  On the dynamics of rational solutions for 1-D generalized Volterra system
# 0.985  The K-Z Equation and the Quantum-Group Difference Equation in Quantum Self-dual Yang-Mills Theory
# 0.985  Multifractal characterisation of complete genomes
# 0.981  Sequences of Levy Transformations and Multi-Wro\'nski Determinant Solutions of the Darboux System
# 0.969  Field theoretic operators for multifractal moments
# ===============
# stat.AP
# 0.997  Correcting for selection bias via cross-validation in the classification of microarray data
# 0.996  A hierarchical Bayesian approach for estimating the origin of a mixed population
# 0.994  Recent Developments in Nonregular Fractional Factorial Designs
# 0.993  The distribution of model averaging estimators and an impossibility result regarding its estimation
# 0.978  The Interval Property in Multiple Testing of Pairwise Differences
# 0.977  Multi-objective optimal designs in comparative clinical trials with covariates: The reinforced doubly adaptive biased coin design
# 0.975  Discussion of 'Estimating Random Effects via Adjustment for Density Maximization' by C. Morris and R. Tang
# 0.975  Rejoinder to 'Multiple Testing for Exploratory Research'
# 0.974  Analysis of 1:1 Matched Cohort Studies and Twin Studies, with Binary Exposures and Binary Outcomes
# 0.973  Discussion of 'Statistical Modeling of Spatial Extremes' by A. C. Davison, S. A. Padoan and M. Ribatet
# ===============
# stat.CO
# 1.000  Adaptive Optimal Scaling of Metropolis-Hastings Algorithms Using the Robbins-Monro Process
# 1.000  Non-asymptotic Error Bounds for Sequential MCMC Methods in Multimodal Settings
# 1.000  On the stability of some controlled Markov chains and its applications to stochastic approximation with Markovian dynamic
# 1.000  Auxiliary Particle filtering within adaptive Metropolis-Hastings Sampling
# 1.000  Convergence of a Particle-based Approximation of the Block Online Expectation Maximization Algorithm
# 1.000  Information Geometry and Sequential Monte Carlo
# 1.000  The pseudo-marginal approach for efficient Monte Carlo computations
# 1.000  On adaptive stratification
# 1.000  Practical drift conditions for subgeometric rates of convergence
# 1.000  Optimal scaling for the transient phase of the random walk Metropolis algorithm: the mean-field limit
# ===============
# stat.ME
# 0.980  The Use of Domination Number of a Random Proximity Catch Digraph for Testing Spatial Patterns of Segregation and Association
# 0.980  Directional Clustering Tests Based on Nearest Neighbor Contingency Tables
# 0.979  QR-Adjustment for Clustering Tests Based on Nearest Neighbor Contingency Tables
# 0.979  Class-Specific Tests of Spatial Segregation Based on Nearest Neighbor Contingency Tables
# 0.976  Discovering findings that replicate from a primary study of high dimension to a follow-up study
# 0.976  Replicability analysis for genome-wide association studies
# 0.975  Stochastic Ordering under Conditional Modelling of Extreme Values: Drug-Induced Liver Injury
# 0.974  Multiscale Adaptive Inference on Conditional Moment Inequalities
# 0.970  Testing Multiple Inequality Hypotheses : A Smoothed Indicator Approach
# 0.965  The Bias and Efficiency of Incomplete-Data Estimators in Small Univariate Normal Samples
# ===============
# stat.ML
# 0.999  Safe Feature Elimination for the LASSO and Sparse Supervised Learning Problems
# 0.999  Better Mini-Batch Algorithms via Accelerated Gradient Methods
# 0.999  PRISMA: PRoximal Iterative SMoothing Algorithm
# 0.999  On the Universality of Online Mirror Descent
# 0.999  The Annealing Sparse Bayesian Learning Algorithm
# 0.999  Sparse approximation property and stable recovery of sparse signals from noisy measurements
# 0.999  Distributed Estimation of a Parametric Field Using Sparse Noisy Data
# 0.999  Confusion Matrix Stability Bounds for Multiclass Classification
# 0.999  Progressive versus Random Projections for Compressive Capture of Images, Lightfields and Higher Dimensional Visual Signals
# 0.999  Transfer Learning Using Feature Selection
# ===============
# stat.OT
# 0.999  Online Bandit Learning against an Adaptive Adversary: from Regret to Policy Regret
# 0.999  Comparison of Nonlinear Phase Noise and Intrachannel Four-Wave-Mixing for RZ-DPSK Signals in Dispersive Transmission Systems
# 0.999  Stochastic method for in-situ damage analysis
# 0.997  On the canonical form of scale mixtures of skew-normal distributions
# 0.996  A Semi-Markov Modulated Interest Rate Model
# 0.996  Elementary bifurcations for a simple dynamical system under non-Gaussian Levy noises
# 0.996  Estimating Failure Probabilities
# 0.995  Improving accuracy and power with transfer learning using a meta-analytic database
# 0.994  A note on the variance of the square components of a normal multivariate within a Euclidean ball
# 0.993  Stochastic Comparisons between first-passage times for Markov Chains
# ===============
# stat.TH
# 0.982  Model Adequacy Checks for Discrete Choice Dynamic Models
# 0.936  Restricted estimation of the cumulative incidence functions corresponding to competing risks
# 0.934  Estimation of the Location of a 0-type or $\infty$-type Singularity by Poisson Observations
# 0.926  Sharp adaptive estimation of the drift function for ergodic diffusions
# 0.909  Inference for stochastic volatility models using time change transformations
# 0.823  Measuring the influence of the k-th largest variable on functions over the unit hypercube
# 0.771  A multivariate piecing-together approach with an application to operational loss data
# 0.766  Bayesian posterior consistency in the functional randomly shifted curves model
# 0.766  Ordinal Risk-Group Classification
# 0.765  A probabilistic algorithm to test local algebraic observability in polynomial time
# ===============
# supr-con
# 0.999  Effect of Superconductivity on the Incommensurate Magnetic Response of Cuprate Superconductors
# 0.999  Scattering by impurity-induced order parameter ``holes'' in d-wave superconductors
# 0.998  A re-examination of the electronic structure of Bi_2Sr_2CaCu_2O_{8+d} and Bi_2Sr_2Cu_1O_{6+d} - An electron-like Fermi Surface and the absence of flat bands at $E_F$
# 0.998  Single-particle spectra near a stripe instability
# 0.998  Parameter-free expression for superconducting Tc in cuprates
# 0.997  Superconductivity in the Chalcogens up to Multimegabar Pressures
# 0.995  Giant nonlinear response of superconducting single crystal niobium in a sweeping magnetic field
# 0.993  Probing inhomogeneities in type II superconductors by means of thermal fluctuations, magnetic fields and isotope effects
# 0.992  Microwave surface impedance of proximity-coupled superconducting (Nb) / spin-glass (CuMn) bilayers
# 0.991  Nonlinear Response of HTSC Thin Film Microwave Resonators in an Applied DC Magnetic Field
# ===============

# %%
with open(fName, 'wb') as f:
    print>>f, 'this fit is in: ' + fitPath + '\n'
    #print>>f, 'the dataset is in: ' + datasetPath + '\n'
    for k in range(0,len(theta[0] + 1)):
        print>>f, '\n--------------------------------\n'
        print>>f, 'category k = ' + str(topic2category[k]) + '\n'
        print>>f, 'random articles from category'
        topArt = topArticles(k)
        for line in topArt:
            print>>f, line
        print>>f,'\nin-field articles'
        inField = inFieldArticles(k)
        for line in inField:
            print>>f,line
        print>>f,'\nout-field articles'
        outField = outFieldArticles(k)
        for line in outField:
            print>>f,line
        print>>f,'\ninter-field articles'
        interField = interFieldArticles(k)
        for line in interField:
            print>>f,line

# %% [markdown]
# look at hep articles that are of most interest to cond-mat

# %%
category2topic = {v:k for k, v in topic2category.items()}

# %%
category2topic
# Out:
# {'acc-phys': 0,
#  'adap-org': 1,
#  'alg-geom': 2,
#  'ao-sci': 3,
#  'astro-ph': 4,
#  'astro-ph.CO': 5,
#  'astro-ph.EP': 6,
#  'astro-ph.GA': 7,
#  'astro-ph.HE': 8,
#  'astro-ph.IM': 9,
#  'astro-ph.SR': 10,
#  'atom-ph': 11,
#  'bayes-an': 12,
#  'chao-dyn': 13,
#  'chem-ph': 14,
#  'cmp-lg': 15,
#  'comp-gas': 16,
#  'cond-mat': 17,
#  'cond-mat.dis-nn': 18,
#  'cond-mat.mes-hall': 19,
#  'cond-mat.mtrl-sci': 20,
#  'cond-mat.other': 21,
#  'cond-mat.quant-gas': 22,
#  'cond-mat.soft': 23,
#  'cond-mat.stat-mech': 24,
#  'cond-mat.str-el': 25,
#  'cond-mat.supr-con': 26,
#  'cs.AI': 27,
#  'cs.AR': 28,
#  'cs.CC': 29,
#  'cs.CE': 30,
#  'cs.CG': 31,
#  'cs.CL': 32,
#  'cs.CR': 33,
#  'cs.CV': 34,
#  'cs.CY': 35,
#  'cs.DB': 36,
#  'cs.DC': 37,
#  'cs.DL': 38,
#  'cs.DM': 39,
#  'cs.DS': 40,
#  'cs.ET': 41,
#  'cs.FL': 42,
#  'cs.GL': 43,
#  'cs.GR': 44,
#  'cs.GT': 45,
#  'cs.HC': 46,
#  'cs.IR': 47,
#  'cs.IT': 48,
#  'cs.LG': 49,
#  'cs.LO': 50,
#  'cs.MA': 51,
#  'cs.MM': 52,
#  'cs.MS': 53,
#  'cs.NA': 54,
#  'cs.NE': 55,
#  'cs.NI': 56,
#  'cs.OH': 57,
#  'cs.OS': 58,
#  'cs.PF': 59,
#  'cs.PL': 60,
#  'cs.RO': 61,
#  'cs.SC': 62,
#  'cs.SD': 63,
#  'cs.SE': 64,
#  'cs.SI': 65,
#  'cs.SY': 66,
#  'dg-ga': 67,
#  'funct-an': 68,
#  'gr-qc': 69,
#  'hep-ex': 70,
#  'hep-lat': 71,
#  'hep-ph': 72,
#  'hep-th': 73,
#  'math-ph': 74,
#  'math.AC': 75,
#  'math.AG': 76,
#  'math.AP': 77,
#  'math.AT': 78,
#  'math.CA': 79,
#  'math.CO': 80,
#  'math.CT': 81,
#  'math.CV': 82,
#  'math.DG': 83,
#  'math.DS': 84,
#  'math.FA': 85,
#  'math.GM': 86,
#  'math.GN': 87,
#  'math.GR': 88,
#  'math.GT': 89,
#  'math.HO': 90,
#  'math.IT': 91,
#  'math.KT': 92,
#  'math.LO': 93,
#  'math.MG': 94,
#  'math.MP': 95,
#  'math.NA': 96,
#  'math.NT': 97,
#  'math.OA': 98,
#  'math.OC': 99,
#  'math.PR': 100,
#  'math.QA': 101,
#  'math.RA': 102,
#  'math.RT': 103,
#  'math.SG': 104,
#  'math.SP': 105,
#  'math.ST': 106,
#  'mtrl-th': 107,
#  'nlin.AO': 108,
#  'nlin.CD': 109,
#  'nlin.CG': 110,
#  'nlin.PS': 111,
#  'nlin.SI': 112,
#  'nucl-ex': 113,
#  'nucl-th': 114,
#  'patt-sol': 115,
#  'physics.acc-ph': 116,
#  'physics.ao-ph': 117,
#  'physics.atm-clus': 118,
#  'physics.atom-ph': 119,
#  'physics.bio-ph': 120,
#  'physics.chem-ph': 121,
#  'physics.class-ph': 122,
#  'physics.comp-ph': 123,
#  'physics.data-an': 124,
#  'physics.ed-ph': 125,
#  'physics.flu-dyn': 126,
#  'physics.gen-ph': 127,
#  'physics.geo-ph': 128,
#  'physics.hist-ph': 129,
#  'physics.ins-det': 130,
#  'physics.med-ph': 131,
#  'physics.optics': 132,
#  'physics.plasm-ph': 133,
#  'physics.pop-ph': 134,
#  'physics.soc-ph': 135,
#  'physics.space-ph': 136,
#  'plasm-ph': 137,
#  'q-alg': 138,
#  'q-bio': 139,
#  'q-bio.BM': 140,
#  'q-bio.CB': 141,
#  'q-bio.GN': 142,
#  'q-bio.MN': 143,
#  'q-bio.NC': 144,
#  'q-bio.OT': 145,
#  'q-bio.PE': 146,
#  'q-bio.QM': 147,
#  'q-bio.SC': 148,
#  'q-bio.TO': 149,
#  'q-fin.CP': 150,
#  'q-fin.GN': 151,
#  'q-fin.PM': 152,
#  'q-fin.PR': 153,
#  'q-fin.RM': 154,
#  'q-fin.ST': 155,
#  'q-fin.TR': 156,
#  'quant-ph': 157,
#  'solv-int': 158,
#  'stat.AP': 159,
#  'stat.CO': 160,
#  'stat.ME': 161,
#  'stat.ML': 162,
#  'stat.OT': 163,
#  'stat.TH': 164,
#  'supr-con': 165}

# %% [markdown]
# try to look at papers in hep that are popular in cond-mat

# %%
def betweenFieldArticles(cat1, cat2, normth = normth, ep = epsilon, n = 10, prop = 0.15):
    k1 = category2topic[cat1]
    k2 = category2topic[cat2]
    # article indices in topic k1
    ind = np.where(normth[:,k1] > prop)
    
    # popularity of articles in k1 in topic k2
    ep_ind = ep[ind,k2][0]
    
    # most popular articles with respect to k2 that are in k1
    top = np.argsort(ep_ind)[::-1]
    betweenField = ["%0.3f  %s" %(ep_ind[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    for line in betweenField:
        print line

betweenFieldArticles('hep-ph', 'cond-mat', ep=normth, n=20)
# Out:
# 0.652  Real Time Dynamics of Soliton Diffusion
# 0.436  Universal statistics of wave functions in chaotic and disordered systems
# 0.436  Heisenberg Spin Glass on a Hypercubic Cell
# 0.425  Localization Bounds for an Electron Gas
# 0.421  Tunneling through a barrier in Tomonaga-Luttinger liquid connected to reservoirs
# 0.419  Dynamical Replica Theory for Disordered Spin Systems
# 0.410  A Non-Perturbative Approach to the Random-Bond Ising Model
# 0.409  Gauge theory of disclinations on fluctuating elastic surfaces
# 0.408  Decaying magnetohydrodynamics: effects of initial conditions
# 0.407  Spectral properties of quantum $N$-body systems versus chaotic properties of their mean field approximations
# 0.402  The Scattering Theory of Oscillator Defects in an Optical Fiber
# 0.400  Deviations from Fermi-liquid behavior above $T_c$ in 2D short coherence length superconductors
# 0.385  Correlations in one dimensional quantum impurity problems with an external field
# 0.382  Topological Defects in the Abrikosov Lattice of Vortices in Type-II Superconductors
# 0.379  Mean Field Description of the Fractional Quantum Hall Effect Near $\nu=1/(2k+1)$
# 0.377  Connection between Calogero-Marchioro-Wolfes type few-body models and free oscillators
# 0.376  Rigorous mean field model for CPA: Anderson model with free random variables
# 0.372  Renormalization group study of interacting electrons
# 0.370  Renormalization Theory of Stochastic Growth
# 0.368  DC--Transport in Quantum Wires

# %%
betweenFieldArticles('stat.ML', 'hep-ex', ep=normth, n=20)
# Out:
# 0.261  Common dependence on earthquake magnitudes for the trapped particles bursts approaching the earthquake
# 0.149  Minimum Variance Multi-Frequency Distortionless Restriction for Digital Wideband Beamformer
# 0.021  Parsimonious Mahalanobis Kernel for the Classification of High Dimensional Data
# 0.019  A Novel Directional Weighted Minimum Deviation (DWMD) Based Filter for Removal of Random Valued Impulse Noise
# 0.005  Partial-Hessian Strategies for Fast Learning of Nonlinear Embeddings
# 0.004  Supercharging Recommender Systems using Taxonomies for Learning User Purchase Behavior
# 0.004  Cumulative distribution networks and the derivative-sum-product algorithm
# 0.004  The Convexity and Design of Composite Multiclass Losses
# 0.004  Are visual dictionaries generalizable?
# 0.004  Discovery of Linguistic Relations Using Lexical Attraction
# 0.004  Parameter-Free Spectral Kernel Learning
# 0.004  Noisy-OR Models with Latent Confounding
# 0.003  Herding Dynamic Weights for Partially Observed Random Field Models
# 0.003  Anytime Planning for Decentralized POMDPs using Expectation Maximization
# 0.003  Bayesian Optimal Active Search and Surveying
# 0.003  An Analytical Approach to Document Clustering Based on Internal Criterion Function
# 0.003  A Novel Approach of Harris Corner Detection of Noisy Images using Adaptive Wavelet Thresholding Technique
# 0.003  A Comparative Study between Moravec and Harris Corner Detection of Noisy Images Using Adaptive Wavelet Thresholding Technique
# 0.002  Effect of Tuned Parameters on a LSA MCQ Answering Model
# 0.002  A Generative Process for Sampling Contractive Auto-Encoders

# %%
betweenFieldArticles('stat.ML', 'stat.ML', ep=normth, n=20)
# Out:
# 0.999  Safe Feature Elimination for the LASSO and Sparse Supervised Learning Problems
# 0.999  Better Mini-Batch Algorithms via Accelerated Gradient Methods
# 0.999  PRISMA: PRoximal Iterative SMoothing Algorithm
# 0.999  On the Universality of Online Mirror Descent
# 0.999  The Annealing Sparse Bayesian Learning Algorithm
# 0.999  Sparse approximation property and stable recovery of sparse signals from noisy measurements
# 0.999  Distributed Estimation of a Parametric Field Using Sparse Noisy Data
# 0.999  Confusion Matrix Stability Bounds for Multiclass Classification
# 0.999  Progressive versus Random Projections for Compressive Capture of Images, Lightfields and Higher Dimensional Visual Signals
# 0.999  Transfer Learning Using Feature Selection
# 0.999  Parallel Coordinate Descent for L1-Regularized Loss Minimization
# 0.999  Adjacency-Faithfulness and Conservative Causal Inference
# 0.999  Measurement Error in Lasso: Impact and Correction
# 0.999  Measurement Design for Detecting Sparse Signals
# 0.999  Coherence-based Partial Exact Recovery Condition for OMP/OLS
# 0.999  Large-Margin kNN Classification Using a Deep Encoder Network
# 0.999  Stochastic convex optimization with bandit feedback
# 0.999  Low-rank matrix factorization with attributes
# 0.999  Sparsity with sign-coherent groups of variables via the cooperative-Lasso
# 0.999  Large-Scale Clustering Based on Data Compression

# %%
betweenFieldArticles('stat.ML', 'physics.data-an', ep=normth, n=20)
# Out:
# 0.415  Autoregressive short-term prediction of turning points using support vector regression
# 0.162  A Novel Bayesian Classifier using Copula Functions
# 0.161  Discovery of non-gaussian linear causal models using ICA
# 0.142  Spatio-temporal Granger causality: a new framework
# 0.139  Noise Invalidation Denoising
# 0.129  Geometric kernel smoothing of tensor fields
# 0.097  Multivariate Goodness of Fit Procedures for Unbinned Data: An Annotated Bibliography
# 0.092  Super-resolution using Sparse Representations over Learned Dictionaries: Reconstruction of Brain Structure using Electron Microscopy
# 0.087  The Loss Rank Principle for Model Selection
# 0.074  Algebraic Signal Processing Theory: Cooley-Tukey Type Algorithms for DCTs and DSTs
# 0.062  Stability Analysis for Regularized Least Squares Regression
# 0.050  Adaptive Online Prediction by Following the Perturbed Leader
# 0.046  Learning Bayesian Networks with the bnlearn R Package
# 0.036  Is Bayes Posterior just Quick and Dirty Confidence?
# 0.035  Separation Theorem for Independent Subspace Analysis with Sufficient Conditions
# 0.017  Variational Bayes approach for model aggregation in unsupervised classification with Markovian dependency
# 0.016  Undercomplete Blind Subspace Deconvolution
# 0.014  Competing with wild prediction rules
# 0.013  Confidence bounds for the sensitivity lack of a less specific diagnostic test, without gold standard
# 0.012  A Note on the PAC Bayesian Theorem

# %% [markdown]
# look up stephan's paper

# %%
id2arxiv_info[id2arxiv_info.arxiv_id == '1008.0468']
# Out:
#          arxiv_id          categories  \
# 589400  1008.0468  cond-mat.quant-gas
#
#                                                     title        date
# 589400  Equilibration rates and negative absolute temp...  2010-08-03

# %%
epsilon_categories = pd.DataFrame(data=normth, columns=category_list)

# %%
epsilon_categories.loc[589400].plot(kind='bar', figsize=(30, 4))

# %% [markdown]
# this is better than the earlier fit - it picks out strongly correlated electronic systems as a category of interest.

# %% [markdown]
# look at sachdev / ads cft

# %%
id2item = id2arxiv_info

# %%
id2item[id2item.arxiv_id == '1002.2947']
# Out:
#         arxiv_id              categories                         title  \
# 32111  1002.2947  hep-th cond-mat.str-el  Condensed matter and AdS/CFT
#
#              date
# 32111  2010-02-16

# %%
topic2category[73]
# Out:
# 'hep-th'

# %%
epsilon_categories.loc[32111].plot(kind='bar', figsize=(30, 4))

# %% [markdown]
# it captures some extraneous interest, but mostly epsilon is large in the categories corresponding to theta

# %% [markdown]
# look at altland & zirnbauer

# %%
id2item[id2item.arxiv_id == 'cond-mat/9602137']
# Out:
#                 arxiv_id categories  \
# 247209  cond-mat/9602137   cond-mat
#
#                                                     title        date
# 247209  Novel Symmetry Classes in Mesoscopic Normal-Su...  1996-02-27

# %%
def plot_eps(doc_id):
    
    display(id2item.iloc[doc_id])
    
    topic = np.where(theta[doc_id]>0)[0][0]

    #print topic2category[topic]

    epsilon_categories.loc[doc_id].plot(kind='bar', figsize=(30, 4))

# %% [markdown]
# * nb: epsilon can't be strictly zero because the likelihood could be zero, but there is a positive prior contribution too.

# %%
plot_eps(247209)
# Out:
# arxiv_id                                       cond-mat/9602137
# categories                                             cond-mat
# title         Novel Symmetry Classes in Mesoscopic Normal-Su...
# date                                                 1996-02-27
# Name: 247209, dtype: object

# %% [markdown]
# * try to back up this 'anomalous' behaviour by estimating the number of citations we'd expect.

# %% [markdown]
# try to look at most 'popular' papers in condensed matter (epsilon should correspond to clicks?)

# %%
def get_top_articles_eps(category, n=10):
    top = epsilon_categories.sort(columns=category, ascending=False)[category]

    top = top[0:n]

    for ID, eps in zip(top.index, top):
        print '{:0.2f}\t {}'.format(eps, id2title[ID])

# %%
get_top_articles_eps('cond-mat')
# Out:
# 15.10	 One-Dimensional Fermi liquids
# 15.02	 Path Integral Methods and Applications
# 13.30	 The Hubbard Model: Some Rigorous Results and Open Problems
# 10.84	 Bosonization for Beginners --- Refermionization for Experts
# 8.62	 The one-dimensional Hubbard model: A reminiscence
# 8.41	 Quantum phase transitions
# 8.21	 A practical guide to computer simulations
# 8.14	 An Introduction into the Feynman Path Integral
# 7.08	 An introduction to bosonization
# 6.99	 Conformal Field Theory Approach to the Kondo Effect

# %%
plot_eps(643098)
# Out:
# arxiv_id                                           math/0311087
# categories                                      math.DG math.PR
# title         Neighbourhoods of independence for random proc...
# date                                                 2003-11-06
# Name: 643098, dtype: object

# %% [markdown]
# this is an article that attracts people in condensed matter and unusually so

# %%
plot_eps(571709)
# Out:
# arxiv_id                                              1206.0390
# categories                                                gr-qc
# title         Cauchy problem with data on a characteristic c...
# date                                                 2012-06-02
# Name: 571709, dtype: object

# %% [markdown]
# look at norm of epsilon to see if it correlates to popularity

# %%
epsilon_norm = np.sqrt(np.square(epsilon_categories).sum(axis=1))

# %%
epsilon_norm.sort(ascending=False)

# %%
display(id2arxiv_info.iloc[2272].categories)
# Out:
# 'hep-ex hep-ph'

# %%
for ID, eps in zip(epsilon_norm[0:10].index, epsilon_norm[0:10]):
    print '{:0.2f} {}\t {}'.format(eps, id2arxiv_info.iloc[ID].categories, id2title[ID])
# Out:
# 56.95 hep-ex hep-ph	 Measurement of the neutrino velocity with the OPERA detector in the CNGS beam
# 52.66 hep-ph hep-ex hep-th	 A Supersymmetry Primer
# 52.46 math.DG	 The entropy formula for the Ricci flow and its geometric applications
# 47.29 hep-th gr-qc hep-lat hep-ph	 Large N Field Theories, String Theory and Gravity
# 45.99 hep-ex	 Invariant Mass Distribution of Jet Pairs Produced in Association with a W boson in ppbar Collisions at sqrt(s) = 1.96 TeV
# 43.73 hep-th	 Anti De Sitter Space And Holography
# 42.28 math.DG	 Ricci flow with surgery on three-manifolds
# 41.79 hep-th	 The Large N Limit of Superconformal Field Theories and Supergravity
# 38.52 astro-ph	 Wilkinson Microwave Anisotropy Probe (WMAP) Three Year Results: Implications for Cosmology
# 36.37 math.DG	 Finite extinction time for the solutions to the Ricci flow on certain three-manifolds

# %% [markdown]
# the proof of innocence is one of the most popular articles on the arxiv in terms of clicks (major press coverage, etc)

# %%
id2item[id2item.arxiv_id == '1204.0162']
# Out:
#         arxiv_id                      categories                   title  \
# 13057  1204.0162  physics.pop-ph physics.data-an  The Proof of Innocence
#
#              date
# 13057  2012-04-01

# %%
plot_eps(13057)
# Out:
# arxiv_id                           1204.0162
# categories    physics.pop-ph physics.data-an
# title                 The Proof of Innocence
# date                              2012-04-01
# Name: 13057, dtype: object

# %% [markdown]
# look at some highly-cited papers (via https://www.quora.com/What-are-some-of-the-most-cited-papers-from-arXiv)
#
# one of the most cited papers in physics: 9711200

# %%
id2item[id2item.arxiv_id == 'hep-th/9711200']
# Out:
#             arxiv_id categories  \
# 8176  hep-th/9711200     hep-th
#
#                                                   title        date
# 8176  The Large N Limit of Superconformal Field Theo...  1997-11-27

# %%
plot_eps(8176)
# Out:
# arxiv_id                                         hep-th/9711200
# categories                                               hep-th
# title         The Large N Limit of Superconformal Field Theo...
# date                                                 1997-11-27
# Name: 8176, dtype: object

# %% [markdown]
# this is OK, but doesn't really capture inderdisciplinary interest.

# %%
lst = ['astro-ph/9812133', 'astro-ph/9805201', 'astro-ph/0302209']

# %%
idlist = []
for idx in range(0,len(lst)):
    idlist.append(id2item[id2item.arxiv_id == lst[idx]].index[0])

# %%
idlist
# Out:
# [5065, 15852, 104]

# %%
for idx in idlist:
    plot_eps(idx)
    plt.show()
    plt.close()
# Out:
# arxiv_id                                       astro-ph/9812133
# categories                               astro-ph hep-ex hep-ph
# title         Measurements of Omega and Lambda from 42 High-...
# date                                                 1998-12-07
# Name: 5065, dtype: object
# arxiv_id                                       astro-ph/9805201
# categories                                             astro-ph
# title         Observational Evidence from Supernovae for an ...
# date                                                 1998-05-14
# Name: 15852, dtype: object
# arxiv_id                                       astro-ph/0302209
# categories                                             astro-ph
# title         First Year Wilkinson Microwave Anisotropy Prob...
# date                                                 2003-02-11
# Name: 104, dtype: object

# %% [markdown]
# ^ this is good: captures interest in the appropriate categories!

# %% [markdown]
# look at histogram for papers in categories

# %%
theta_categories = pd.DataFrame(data=theta, columns=category_list)

# %%
theta_categories.sum().plot(kind='bar',figsize=(30, 4), title='number of papers in each arxiv category')

# %% [markdown]
# which categories have the most 'surprise'? i.e., the highest average theta?

# %%
epsilon_describe = epsilon_categories.describe()

# %%
epsilon_describe
# Out:
#             acc-phys       adap-org       alg-geom         ao-sci  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.000397       0.004488       0.009155       0.000146
# std         0.000172       0.002633       0.003966       0.000154
# min         0.000392       0.004408       0.008935       0.000143
# 25%         0.000394       0.004436       0.008986       0.000144
# 50%         0.000395       0.004456       0.009027       0.000145
# 75%         0.000398       0.004489       0.009095       0.000146
# max         0.099943       1.437330       0.878982       0.068097
#
#             astro-ph    astro-ph.CO    astro-ph.EP    astro-ph.GA  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.079975       0.034101       0.013193       0.025115
# std         0.356219       0.199619       0.089457       0.135110
# min         0.010505       0.004270       0.005480       0.007149
# 25%         0.010512       0.004272       0.005487       0.007156
# 50%         0.010572       0.004282       0.005496       0.007166
# 75%         0.010960       0.004378       0.005530       0.007242
# max        37.045288      23.066647       7.863973       7.654246
#
#          astro-ph.HE    astro-ph.IM      ...             q-fin.TR  \
# count  806139.000000  806139.000000      ...        806139.000000
# mean        0.028822       0.012223      ...             0.003425
# std         0.153835       0.067661      ...             0.002365
# min         0.006170       0.008137      ...             0.003335
# 25%         0.006176       0.008154      ...             0.003354
# 50%         0.006194       0.008176      ...             0.003368
# 75%         0.006299       0.008302      ...             0.003391
# max         9.656222      10.899772      ...             0.656660
#
#             quant-ph       solv-int        stat.AP        stat.CO  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.065172       0.010417       0.012819       0.006291
# std         0.328855       0.002438       0.018271       0.009281
# min         0.008875       0.010198       0.012492       0.005958
# 25%         0.008891       0.010266       0.012557       0.005988
# 50%         0.008945       0.010320       0.012608       0.006010
# 75%         0.009124       0.010420       0.012692       0.006048
# max        27.446476       0.883993      13.902493       1.344002
#
#              stat.ME        stat.ML        stat.OT        stat.TH  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.014428       0.012262       0.000983       0.026668
# std         0.016008       0.036973       0.000192       0.037994
# min         0.013597       0.010399       0.000970       0.023884
# 25%         0.013659       0.010440       0.000976       0.023986
# 50%         0.013706       0.010470       0.000980       0.024067
# 75%         0.013787       0.010523       0.000986       0.024213
# max         2.641249       4.189933       0.108122       4.693662
#
#             supr-con
# count  806139.000000
# mean        0.001434
# std         0.000174
# min         0.001415
# 25%         0.001423
# 50%         0.001429
# 75%         0.001439
# max         0.113408
#
# [8 rows x 166 columns]

# %%
epsilon_describe.iloc[7,:].plot(kind='bar', figsize=(30, 4), title='maximum epsilon per category')

# %%
epsilon_describe.iloc[1,:].plot(kind='bar', figsize=(30, 4), title='mean epsilon per category')

# %%
epsilon_describe.iloc[2,:].plot(kind='bar', figsize=(30, 4), title='epsilon std per category')

# %%
epsilon_describe.iloc[3,:].plot(kind='bar', figsize=(30, 4), title='epsilon min per category')

# %% [markdown]
# plot epsilon min and number of papers per category

# %%
eps_min = epsilon_describe.iloc[3,:]

# %%
num_articles_per_category = theta_categories.sum()

# %%
eps_min_and_num = pd.concat([eps_min, num_articles_per_category], axis=1).T

# %%
eps_min_and_num.index = ['min', 'num_articles']

# %%
eps_min_and_num.T.plot(kind='bar', figsize=(30, 4), title='minimum epsilon and number of articles per category', logy=True)
