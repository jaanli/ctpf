# %%
# %matplotlib inline

# %% [markdown]
# goal:
#
# an analysis with specific papers.
# look at interdisciplinary papers, within discipline papers, and any
# new post-hoc statistics that you think could be interesting.  for how
# to do this, see our papers on collaborative topic modeling and my talk
# about it (all on my website).  ask me if you are confused how to do
# this.  i'm also interested in how this model fails on this data.  (we
# know it must.)
#
# a super thorough look at
# this model would also consider the held out predictions and specific
# users.  you would understand their interests via their clicks, and how
# the model has captured or not captured them.

# %%
# replicate the functionality of explore-coll-msd-tm.R for posterity and general ease of use
import numpy as np
import cPickle as pickle
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')
import matplotlib.pyplot as plt
from IPython.display import display



#fitPath = "/scratch/shared/music_project/jaan/ctpf-fits/collabtm/src/nusers1128835-ndocs202994-nvocab256-k50-batch-bin-vb-fa-ldainit/"

# fit path
fitPath = '/home/waldorf/altosaar/projects/arxiv/fit/vanilla-pf-fixed/'

# output file
fName = fitPath + 'arxiv-categories-ctpf.txt'

# maps
in_dir = '/home/statler/lcharlin/arxiv/dat/dataset_2003-2012/'
id2arxiv_info = pd.read_csv(in_dir + 'items_arxiv_info.tsv', header=None, delimiter='\t', names=['arxiv_id', 'categories', 'title', 'date'])

drop_indices = id2arxiv_info['categories'].isnull()

drop_indices_list = list(np.where(drop_indices == True)[0])

kept_indices_list = list(np.where(drop_indices == False)[0])

kept_did_list = map(lambda x:x+1, kept_indices_list)

print 'num kept is ' + str(len(kept_did_list))

print 'num dropped indices is ' + str(len(id2arxiv_info[drop_indices]))

id2arxiv_info = id2arxiv_info[~drop_indices]
# Out:
# num kept is 806139
# num dropped indices is 19568

# %% [markdown]
# check that we have the right categories in the map:

# %%
document_category_dummies = id2arxiv_info['categories'].str.join(sep='').str.get_dummies(sep=' ')
category_list = list(document_category_dummies.columns)

# %%
observed_categories = document_category_dummies.as_matrix().astype(np.float32)

# %%
topic2category = {k:category for k, category in enumerate(category_list)}

# %% [markdown]
# # NB: here theta = topic matrix, but in my fits, theta = user prefs matrix!

# %%
# # load theta
# for fixed (observed) theta the code adds a small prior value (0.0308...) to each entry
# tName = fitPath + 'theta.tsv'
# # skip first two cols, and first row
# theta = pd.read_csv(tName, delimiter='\t', header=None).iloc[0:,2:]

# this is the fixed theta (according to arxiv category)
tName = fitPath + 'Et.pkl'
theta = observed_categories #pickle.load(open(tName, 'rb'))#pd.read_csv(tName, delimiter=' ', header=None)

# %%
#theta = theta.as_matrix()
# normalize
# def normalizeRow(row):
#     return row / np.sum(row)
#theta.apply(normalizeRow, axis=0)

# num topics
k = len(theta[0])

# load epsilon
eName = fitPath + 'Eba-ie-epsilon.pkl'

# skip first 2 cols
epsilon = pickle.load(open(eName, 'rb'))#pd.read_csv(eName, delimiter='\t', header=None).iloc[0:,2:]

# %%
#epsilon = epsilon.as_matrix()

# load id2word
#mapName = '/scratch/shared/music_project/jaan/lda-fits/dat/id2word.pickle'
#id2word = pickle.load(open(mapName, 'rb'))

th_ep = theta + epsilon
th_ep_rs = np.sum(th_ep,axis=1)

# %%
id2arxiv_info.index = range(0, len(id2arxiv_info))

# %%
id2item_dict = id2arxiv_info.to_dict()

id2title = id2item_dict['title']
#id2title[0] = 'dummy title'
normth = theta

# %% [markdown]
# now we're ready to check if the observed topics match what's in our article id to title/arxiv id map. it checks out:

# %%
print np.where(theta[3434] == 1)
print topic2category[np.where(theta[3434] == 1)[0][0]]

print id2title[3434]
# Out:
# (array([19, 26]),)
# cond-mat.mes-hall
# Effects of a Fluctuating Interface between a Superfluid and a Polarized Fermi Gas

# %%
topic2category[26], topic2category[19]
# Out:
# ('cond-mat.supr-con', 'cond-mat.mes-hall')

# %%
print th_ep.shape, th_ep_rs.shape
# Out:
# (806139, 166) (806139,)

# %%
# number of articles in category 0.
np.where(normth[:,0] > 0)[0].shape
# Out:
# (47,)

# %%
#working
def similarArticles(docId, theta, n):
    sqrt_normed_theta = np.sqrt(normth[docId])
    a = np.sum(np.power(np.sqrt(normththeta) - sqrt_normed_theta,2),axis=1)
    # this was in reverse
    top = np.argsort(a)
    for topId in top[0:n]:
        print "%0.3f  %s" %(a[topId],id2title[topId])

#working
def topArticles(k,normth=normth,n=10):
    top = np.argsort(normth[:,k])[::-1]
    return ["%0.3f  %s" %(normth[topId,k],id2title[topId]) for topId in top[0:n]]
    #for topId in top[0:n]:
        #print "%0.3f  %s" %(normth[topId,k],id2title[topId]))
        
#working! mistake was that i added normalized theta to eps for th_ep.
def inFieldArticles(k,th_ep=th_ep,normth=normth,n=10,prop=0.15):
    ind = np.where(normth[:,k] > prop)
    th_ep_ind = th_ep[ind,k][0]
    top = np.argsort(th_ep_ind)[::-1]
    return ["%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    #for topId in top[0:n]:
     #   print "%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]]) 
        
#working
def outFieldArticles(k, th_ep=th_ep, normth=normth, n=10, prop=0.05):
    ind = np.where(normth[:,k] < prop)
    th_ep_ind = th_ep[ind,k][0]
    top = np.argsort(th_ep_ind)[::-1]
    return ["%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    #for topId in top[0:n]:
     #   print "%0.3f  %s" %(th_ep_ind[topId],id2title[ind[0][topId]])

#working
def interFieldArticles(k, rs = th_ep_rs, th_ep = th_ep, n = 10, prop = 0.15):
    ind = np.where(normth[:,k] > prop)
    rs_ind = rs[ind]
    th_ep_ind = th_ep[ind,k][0]
    score = rs_ind - th_ep_ind
    top = np.argsort(score)[::-1]
    return ["%0.3f  %s" %(score[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    #for topId in top[0:n]:
    #    print "%0.3f  %s" %(score[topId],id2title[ind[0][topId]])

# %%
with open(fName, 'wb') as f:
    print>>f, 'this fit is in: ' + fitPath + '\n'
    #print>>f, 'the dataset is in: ' + datasetPath + '\n'
    for k in range(0,len(theta[0] + 1)):
        print>>f, '\n--------------------------------\n'
        print>>f, 'category k = ' + str(topic2category[k]) + '\n'
        print>>f, 'random articles from category'
        topArt = topArticles(k)
        for line in topArt:
            print>>f, line
        print>>f,'\nin-field articles'
        inField = inFieldArticles(k)
        for line in inField:
            print>>f,line
        print>>f,'\nout-field articles'
        outField = outFieldArticles(k)
        for line in outField:
            print>>f,line
        print>>f,'\ninter-field articles'
        interField = interFieldArticles(k)
        for line in interField:
            print>>f,line

# %% [markdown]
# look at hep articles that are of most interest to cond-mat

# %%
category2topic = {v:k for k, v in topic2category.items()}

# %%
category2topic
# Out:
# {'acc-phys': 0,
#  'adap-org': 1,
#  'alg-geom': 2,
#  'ao-sci': 3,
#  'astro-ph': 4,
#  'astro-ph.CO': 5,
#  'astro-ph.EP': 6,
#  'astro-ph.GA': 7,
#  'astro-ph.HE': 8,
#  'astro-ph.IM': 9,
#  'astro-ph.SR': 10,
#  'atom-ph': 11,
#  'bayes-an': 12,
#  'chao-dyn': 13,
#  'chem-ph': 14,
#  'cmp-lg': 15,
#  'comp-gas': 16,
#  'cond-mat': 17,
#  'cond-mat.dis-nn': 18,
#  'cond-mat.mes-hall': 19,
#  'cond-mat.mtrl-sci': 20,
#  'cond-mat.other': 21,
#  'cond-mat.quant-gas': 22,
#  'cond-mat.soft': 23,
#  'cond-mat.stat-mech': 24,
#  'cond-mat.str-el': 25,
#  'cond-mat.supr-con': 26,
#  'cs.AI': 27,
#  'cs.AR': 28,
#  'cs.CC': 29,
#  'cs.CE': 30,
#  'cs.CG': 31,
#  'cs.CL': 32,
#  'cs.CR': 33,
#  'cs.CV': 34,
#  'cs.CY': 35,
#  'cs.DB': 36,
#  'cs.DC': 37,
#  'cs.DL': 38,
#  'cs.DM': 39,
#  'cs.DS': 40,
#  'cs.ET': 41,
#  'cs.FL': 42,
#  'cs.GL': 43,
#  'cs.GR': 44,
#  'cs.GT': 45,
#  'cs.HC': 46,
#  'cs.IR': 47,
#  'cs.IT': 48,
#  'cs.LG': 49,
#  'cs.LO': 50,
#  'cs.MA': 51,
#  'cs.MM': 52,
#  'cs.MS': 53,
#  'cs.NA': 54,
#  'cs.NE': 55,
#  'cs.NI': 56,
#  'cs.OH': 57,
#  'cs.OS': 58,
#  'cs.PF': 59,
#  'cs.PL': 60,
#  'cs.RO': 61,
#  'cs.SC': 62,
#  'cs.SD': 63,
#  'cs.SE': 64,
#  'cs.SI': 65,
#  'cs.SY': 66,
#  'dg-ga': 67,
#  'funct-an': 68,
#  'gr-qc': 69,
#  'hep-ex': 70,
#  'hep-lat': 71,
#  'hep-ph': 72,
#  'hep-th': 73,
#  'math-ph': 74,
#  'math.AC': 75,
#  'math.AG': 76,
#  'math.AP': 77,
#  'math.AT': 78,
#  'math.CA': 79,
#  'math.CO': 80,
#  'math.CT': 81,
#  'math.CV': 82,
#  'math.DG': 83,
#  'math.DS': 84,
#  'math.FA': 85,
#  'math.GM': 86,
#  'math.GN': 87,
#  'math.GR': 88,
#  'math.GT': 89,
#  'math.HO': 90,
#  'math.IT': 91,
#  'math.KT': 92,
#  'math.LO': 93,
#  'math.MG': 94,
#  'math.MP': 95,
#  'math.NA': 96,
#  'math.NT': 97,
#  'math.OA': 98,
#  'math.OC': 99,
#  'math.PR': 100,
#  'math.QA': 101,
#  'math.RA': 102,
#  'math.RT': 103,
#  'math.SG': 104,
#  'math.SP': 105,
#  'math.ST': 106,
#  'mtrl-th': 107,
#  'nlin.AO': 108,
#  'nlin.CD': 109,
#  'nlin.CG': 110,
#  'nlin.PS': 111,
#  'nlin.SI': 112,
#  'nucl-ex': 113,
#  'nucl-th': 114,
#  'patt-sol': 115,
#  'physics.acc-ph': 116,
#  'physics.ao-ph': 117,
#  'physics.atm-clus': 118,
#  'physics.atom-ph': 119,
#  'physics.bio-ph': 120,
#  'physics.chem-ph': 121,
#  'physics.class-ph': 122,
#  'physics.comp-ph': 123,
#  'physics.data-an': 124,
#  'physics.ed-ph': 125,
#  'physics.flu-dyn': 126,
#  'physics.gen-ph': 127,
#  'physics.geo-ph': 128,
#  'physics.hist-ph': 129,
#  'physics.ins-det': 130,
#  'physics.med-ph': 131,
#  'physics.optics': 132,
#  'physics.plasm-ph': 133,
#  'physics.pop-ph': 134,
#  'physics.soc-ph': 135,
#  'physics.space-ph': 136,
#  'plasm-ph': 137,
#  'q-alg': 138,
#  'q-bio': 139,
#  'q-bio.BM': 140,
#  'q-bio.CB': 141,
#  'q-bio.GN': 142,
#  'q-bio.MN': 143,
#  'q-bio.NC': 144,
#  'q-bio.OT': 145,
#  'q-bio.PE': 146,
#  'q-bio.QM': 147,
#  'q-bio.SC': 148,
#  'q-bio.TO': 149,
#  'q-fin.CP': 150,
#  'q-fin.GN': 151,
#  'q-fin.PM': 152,
#  'q-fin.PR': 153,
#  'q-fin.RM': 154,
#  'q-fin.ST': 155,
#  'q-fin.TR': 156,
#  'quant-ph': 157,
#  'solv-int': 158,
#  'stat.AP': 159,
#  'stat.CO': 160,
#  'stat.ME': 161,
#  'stat.ML': 162,
#  'stat.OT': 163,
#  'stat.TH': 164,
#  'supr-con': 165}

# %% [markdown]
# try to look at papers in hep that are popular in cond-mat

# %%
def betweenFieldArticles(cat1, cat2, normth = normth, ep = epsilon, n = 10, prop = 0.15):
    k1 = category2topic[cat1]
    k2 = category2topic[cat2]
    # article indices in topic k1
    ind = np.where(normth[:,k1] > prop)
    
    # popularity of articles in k1 in topic k2
    ep_ind = ep[ind,k2][0]
    
    # most popular articles with respect to k2 that are in k1
    top = np.argsort(ep_ind)[::-1]
    betweenField = ["%0.3f  %s" %(top[topId],id2title[ind[0][topId]]) for topId in top[0:n]]
    for line in betweenField:
        print line

betweenFieldArticles('hep-ph', 'cond-mat', n=20)
# Out:
# 24051.000  Drawing Feynman Diagrams with LaTeX and Metafont
# 52106.000  Some Basic Aspects of Fractional Quantum Numbers
# 98522.000  Non-Perturbative Renormalization Flow in Quantum Field Theory and Statistical Physics
# 47869.000  Evaluating Sums over the Matsubara Frequencies
# 89969.000  Fields
# 98247.000  Wick's Theorem at Finite Temperature
# 16399.000  A Goldstone Boson Primer
# 60187.000  Nonperturbative XY-model approach to strong coupling superconductivity in two and three dimensions
# 76419.000  Quantum Field Theory at Finite Temperature: An Introduction
# 95477.000  What exactly is a Skyrmion?
# 94161.000  Theta-terms in nonlinear sigma-models
# 73550.000  Symmetry breaking and defects
# 76612.000  Introduction to Monte Carlo methods
# 33104.000  Nonlinear sigma model approach for phase disorder transitions and the pseudogap phase in chiral Gross-Neveu, Nambu-Jona-Lasinio models and strong-coupling superconductors
# 95565.000  The Exact Renormalisation Group and Approximate Solutions
# 80117.000  Superfluid analogies of cosmological phenomena
# 72656.000  Vortex Formation and Dynamics in Superfluid 3He and Analogies in Quantum Field Theory
# 47495.000  The Condensed Matter Physics of QCD
# 88740.000  Goldstone and Pseudo-Goldstone Bosons in Nuclear, Particle and Condensed-Matter Physics
# 13039.000  Monopole, half-quantum vortices and nexus in chiral superfluids and superconductors

# %% [markdown]
# ^ this is very cool! it picks out:
#
# 80117.000  Superfluid analogies of cosmological phenomena
#
# 76419.000  Quantum Field Theory at Finite Temperature: An Introduction
#
# 47495.000  The Condensed Matter Physics of QCD
#
# 88740.000  Goldstone and Pseudo-Goldstone Bosons in Nuclear, Particle and Condensed-Matter Physics
#
# 73550.000  Symmetry breaking and defects
#
# as being of interest to both high energy and condensed matter people, which is what i expected!
#
# the next step could be:
#
# * use the exposure model to account for whether or not physicists actually considered the articles in ML to get better performance in these types of tasks. right now there's still some junk

# %%
betweenFieldArticles('stat.ML', 'hep-ex', n=20)
# Out:
# 46.000  Machine learning approach to inverse problem and unfolding procedure
# 669.000  Semi-Supervised Anomaly Detection - Towards Model-Independent Searches of New Physics
# 1055.000  Dynamic quantum clustering: a method for visual exploration of structures in data
# 49.000  Classifying extremely imbalanced data sets
# 1128.000  PDE-Foam - a probability-density estimation method using self-adapting phase-space binning
# 1166.000  Isoelastic Agents and Wealth Updates in Machine Learning Markets
# 1329.000  BAMBI: blind accelerated multimodal Bayesian inference
# 1507.000  Clustering Stability: An Overview
# 1056.000  A Privacy-Aware Bayesian Approach for Combining Classifier and Cluster Ensembles
# 1594.000  Classification by Set Cover: The Prototype Vector Machine
# 122.000  Generalised elastic nets
# 1505.000  Sparse matrix-variate Gaussian process blockmodels for network modeling
# 872.000  Fast ABC-Boost for Multi-Class Classification
# 528.000  Near-Optimal Target Learning With Stochastic Binary Signals
# 778.000  Self-configuration from a Machine-Learning Perspective
# 1423.000  A GMBCG Galaxy Cluster Catalog of 55,424 Rich Clusters from SDSS DR7
# 1787.000  A Slice Sampler for Restricted Hierarchical Beta Process with Applications to Shared Subspace Learning
# 283.000  Increasing stability and interpretability of gene expression signatures
# 370.000  Text Data Mining: Theory and Methods
# 726.000  The ILIUM forward modelling algorithm for multivariate parameter estimation and its application to derive stellar parameters from Gaia spectrophotometry

# %%
betweenFieldArticles('stat.ML', 'stat.ML', n=20)
# Out:
# 1317.000  High-dimensional regression with noisy and missing data: Provable guarantees with nonconvexity
# 1367.000  Noisy matrix decomposition via convex relaxation: Optimal rates in high dimensions
# 557.000  Fast global convergence of gradient methods for high-dimensional statistical recovery
# 1244.000  Structured Variable Selection with Sparsity-Inducing Norms
# 603.000  Matrix Completion from a Few Entries
# 1694.000  A Scalable Bootstrap for Massive Data
# 657.000  An Introduction to Conditional Random Fields
# 319.000  A Spectral Algorithm for Latent Dirichlet Allocation
# 924.000  Ergodic Mirror Descent
# 43.000  Distributed Matrix Completion and Robust Factorization
# 482.000  Stochastic Variational Inference
# 157.000  A survey of statistical network models
# 917.000  Revisiting k-means: New Algorithms via Bayesian Nonparametrics
# 972.000  A General Framework of Dual Certificate Analysis for Structured Sparse Recovery Problems
# 607.000  Optimization with Sparsity-Inducing Penalties
# 22.000  Stochastic optimization and sparse statistical recovery: An optimal algorithm for high dimensions
# 384.000  High Dimensional Semiparametric Gaussian Copula Graphical Models
# 1252.000  Sparse Nonparametric Graphical Models
# 381.000  Task-Driven Dictionary Learning
# 1345.000  A General Theory of Concave Regularization for High Dimensional Sparse Estimation Problems

# %%
betweenFieldArticles(category2topic['stat.ML'], category2topic['hep-ex'], n=20)

# %%
betweenFieldArticles(category2topic['stat.ML'], category2topic['physics.data-an'], n=20)

# %%
id2item.sort(columns='date', ascending=False)
# Out:
#                  arxiv_id                                           category  \
# 15444           1212.6238                                    cond-mat.str-el
# 17698           1212.6152                                            math.NT
# 29611           1212.6132                  cond-mat.str-el cond-mat.mtrl-sci
# 30105           1212.6163                        quant-ph cond-mat.stat-mech
# 33290           1212.6153         astro-ph.CO hep-ex nucl-ex physics.ins-det
# 34462           1212.6131                                astro-ph.HE nucl-th
# 38489           1212.6154                                 hep-ph astro-ph.CO
# 42792           1212.6158                                        astro-ph.CO
# 53697           1212.6237                                        astro-ph.IM
# 66576           1212.6225                                      cs.IT math.IT
# 70736           1212.6228                                             hep-th
# 71014           1212.6249                    hep-th math-ph math.MP quant-ph
# 80770           1212.6208                                      hep-ph hep-ex
# 84257           1212.6136          quant-ph cond-mat.mes-hall cond-mat.other
# 88216           1212.6250                            cs.MM cs.CY cs.GR cs.HC
# 108243          1212.6257                                             hep-th
# 122033          1212.6134                      hep-ph hep-ex hep-lat nucl-th
# 127096          1212.6126                                            nlin.SI
# 148310          1212.6212  cond-mat.quant-gas cond-mat.str-el physics.ato...
# 151983          1212.6191                                  cond-mat.mes-hall
# 154299          1212.6188                cond-mat.supr-con cond-mat.mes-hall
# 164172          1212.6227                                            math.DG
# 164867          1212.6229                                             hep-th
# 165807          1212.6220                                       hep-th gr-qc
# 167268          1212.6233                                             hep-ph
# 167679          1212.6156  cond-mat.stat-mech hep-th math-ph math.MP math.RT
# 172691          1212.6214                                  astro-ph.CO gr-qc
# 173601          1212.6256                             math-ph hep-th math.MP
# 175865          1212.6141                                        astro-ph.IM
# 182635          1212.6144                                      cond-mat.soft
# ...                   ...                                                ...
# 610680    hep--ph/0002287                                                NaN
# 611442   cond-mat/0404097                                                NaN
# 622808    hep--th/9602064                                                NaN
# 624333  quant--ph/9608006                                                NaN
# 629043       grqc/0507014                                                NaN
# 631653    hep--th/9701060                                                NaN
# 640070  quant--ph/9802007                                                NaN
# 659382    condmat/0305681                                                NaN
# 663560       grqc/9910076                                                NaN
# 692191  astro--ph/9712057                                                NaN
# 692894  astro--ph/0506534                                                NaN
# 711037  quant--ph/9608049                                                NaN
# 715470   hep--lat/9412104                                                NaN
# 727213  alg--geom/9310003                                                NaN
# 731267    condmat/0703762                                                NaN
# 738858     gr--qc/9506079                                                NaN
# 741629  quant--ph/0304042                                                NaN
# 743045    hep--th/9612125                                                NaN
# 749217    hep--th/0004134                                                NaN
# 760351    hep--th/9512105                                                NaN
# 762772    hep--th/9804085                                                NaN
# 768705  astro--ph/0511730                                                NaN
# 771782    hep--th/9711162                                                NaN
# 774398  astro--ph/0202488                                                NaN
# 785193    condmat/0305461                                                NaN
# 801463    condmat/0309045                                                NaN
# 802220    hep--ph/9909429                                                NaN
# 805020    hep--ph/9908433                                                NaN
# 805667    condmat/9706074                                                NaN
# 824786       r-qc/9706002                                                NaN
#
#                                                     title        date
# 15444   Soft lattice dynamics from broken electronic s...  2012-12-26
# 17698   Modular parametrizations of certain elliptic c...  2012-12-26
# 29611   Epitaxial strain induced magnetic transitions ...  2012-12-26
# 30105   Computing complexity measures for quantum stat...  2012-12-26
# 33290   Search for solar axions in XMASS, a large liqu...  2012-12-26
# 34462   Numerical modeling of core-collapse supernovae...  2012-12-26
# 38489                        Neutrino mass from Cosmology  2012-12-26
# 42792   Diffuse light in the young cluster of galaxies...  2012-12-26
# 53697              NICHE: The Non-Imaging CHErenkov Array  2012-12-26
# 66576   Joint Sensing and Power Allocation in Nonconve...  2012-12-26
# 70736   From the Holomorphic Wilson Loop to `d log' Lo...  2012-12-26
# 71014              Torque Anomaly in Quantum Field Theory  2012-12-26
# 80770   Multi high charged scalars in the LHC searches...  2012-12-26
# 84257   Heralded entanglement between solid-state qubi...  2012-12-26
# 88216   Computer-Assisted Interactive Documentary and ...  2012-12-26
# 108243            CSW-like Expansion for Einstein Gravity  2012-12-26
# 122033  Isospin symmetry breaking and baryon-isospin c...  2012-12-26
# 127096  A systemic method to construct the high order ...  2012-12-26
# 148310  Investigating polaron transitions with polar m...  2012-12-26
# 151983                 Statistical Topological Insulators  2012-12-26
# 154299             Sticky Normal-Superconductor Interface  2012-12-26
# 164172          The K\'ahler-Ricci flow on Fano manifolds  2012-12-26
# 164867         Anomaly Inflow and Membranes in QCD Vacuum  2012-12-26
# 165807  Thermodynamics of conformal fields in topologi...  2012-12-26
# 167268  Complete three-loop QCD corrections to the dec...  2012-12-26
# 167679  Non-local representations of the ageing algebr...  2012-12-26
# 172691  Density Perturbation Growth in Teleparallel Co...  2012-12-26
# 173601  Chern-Simons Theory with Wilson Lines and Boun...  2012-12-26
# 175865  Performance Analysis of Differential Speckle P...  2012-12-26
# 182635       Simple flexible polymers in a spherical cage  2012-12-26
# ...                                                   ...         ...
# 610680                                              Error         NaN
# 611442                                                NaN         NaN
# 622808                                              Error         NaN
# 624333                                              Error         NaN
# 629043                                                NaN         NaN
# 631653                                              Error         NaN
# 640070                                              Error         NaN
# 659382                                                NaN         NaN
# 663560                                                NaN         NaN
# 692191                                              Error         NaN
# 692894                                              Error         NaN
# 711037                                              Error         NaN
# 715470                                              Error         NaN
# 727213                                              Error         NaN
# 731267                                                NaN         NaN
# 738858                                              Error         NaN
# 741629                                              Error         NaN
# 743045                                              Error         NaN
# 749217                                              Error         NaN
# 760351                                              Error         NaN
# 762772                                              Error         NaN
# 768705                                              Error         NaN
# 771782                                              Error         NaN
# 774398                                              Error         NaN
# 785193                                                NaN         NaN
# 801463                                                NaN         NaN
# 802220                                              Error         NaN
# 805020                                              Error         NaN
# 805667                                                NaN         NaN
# 824786                                                NaN         NaN
#
# [825707 rows x 4 columns]

# %% [markdown]
# look up stephan's paper

# %%
id2arxiv_info[id2arxiv_info.arxiv_id == '1008.0468']
# Out:
#          arxiv_id          categories  \
# 589400  1008.0468  cond-mat.quant-gas
#
#                                                     title        date
# 589400  Equilibration rates and negative absolute temp...  2010-08-03

# %%
epsilon_categories = pd.DataFrame(data=epsilon, columns=category_list)

# %%
np.where(theta[589400] > 0)
# Out:
# (array([22]),)

# %%
topic2category[22]
# Out:
# 'cond-mat.quant-gas'

# %%
epsilon_categories.loc[589400].plot(kind='bar', figsize=(30, 4))

# %% [markdown]
# this is better than the earlier fit - it picks out strongly correlated electronic systems as a category of interest.

# %% [markdown]
# look at sachdev / ads cft

# %%
id2item = id2arxiv_info

# %%
id2item[id2item.arxiv_id == '1002.2947']
# Out:
#         arxiv_id              categories                         title  \
# 32111  1002.2947  hep-th cond-mat.str-el  Condensed matter and AdS/CFT
#
#              date
# 32111  2010-02-16

# %%
np.where(theta[32111]>0)
# Out:
# (array([25, 73]),)

# %%
topic2category[73]
# Out:
# 'hep-th'

# %%
epsilon_categories.loc[32111].plot(kind='bar', figsize=(30, 4))

# %% [markdown]
# it captures some extraneous interest, but mostly epsilon is large in the categories corresponding to theta

# %% [markdown]
# look at altland & zirnbauer

# %%
id2item[id2item.arxiv_id == 'cond-mat/9602137']
# Out:
#                 arxiv_id categories  \
# 247209  cond-mat/9602137   cond-mat
#
#                                                     title        date
# 247209  Novel Symmetry Classes in Mesoscopic Normal-Su...  1996-02-27

# %%
def plot_eps(doc_id):
    
    display(id2item.iloc[doc_id])
    
    topic = np.where(theta[doc_id]>0)[0][0]

    #print topic2category[topic]

    epsilon_categories.loc[doc_id].plot(kind='bar', figsize=(30, 4))

# %% [markdown]
# * nb: epsilon can't be strictly zero because the likelihood could be zero, but there is a positive prior contribution too.

# %%
epsilon[247209]
# Out:
# array([  3.98856466e-04,   4.48888063e-03,   9.28667904e-03,
#          1.46071961e-04,   1.06190052e-02,   4.28488443e-03,
#          5.49944045e-03,   7.16435648e-03,   6.18916102e-03,
#          8.18019690e-03,   1.00378303e-02,   1.01355634e-03,
#          1.36927480e-04,   1.74031282e-02,   2.00249313e-03,
#          3.22209328e-03,   1.77397172e-03,   2.57869994e+00,
#          1.92614353e-02,   1.46920488e+00,   2.56995107e-02,
#          1.31345296e-02,   3.68287453e-02,   2.11713343e-02,
#          1.77302685e-02,   3.86094481e-01,   2.04701674e-02,
#          2.49661279e-02,   2.87866357e-03,   1.04892667e-02,
#          7.20547266e-03,   7.89587693e-03,   1.07024529e-02,
#          1.68792403e-02,   1.17344612e-02,   5.93539592e-03,
#          1.05028672e-02,   1.57574011e-02,   5.34596109e-03,
#          1.60918358e-02,   1.31544538e-02,   1.33325884e-03,
#          5.63096212e-03,   7.98011137e-04,   2.21916673e-03,
#          9.37874939e-03,   5.66189694e-03,   9.62114645e-03,
#          2.30443706e-02,   1.55977828e-02,   1.89336550e-02,
#          5.17553612e-03,   3.73899081e-03,   2.94023726e-03,
#          5.52596641e-03,   8.41433459e-03,   2.14101762e-02,
#          6.18954472e-03,   1.34805317e-03,   4.63639717e-03,
#          9.50554911e-03,   4.59070876e-03,   4.58253719e-03,
#          1.13433658e-03,   1.05437179e-02,   8.50493357e-03,
#          8.29404599e-03,   5.52177082e-03,   3.44010160e-03,
#          9.08147351e-03,   8.94968031e-03,   3.94375759e-02,
#          8.92333355e-03,   2.25153378e-01,   7.62335065e-01,
#          1.39051716e-02,   9.83483396e-03,   2.04071806e-02,
#          1.10934533e-02,   1.71691699e-02,   1.66388302e-02,
#          7.91174926e-03,   1.70310811e-02,   1.34923380e-02,
#          2.18019408e-02,   2.40153336e-02,   6.65316830e-03,
#          1.07981718e-02,   5.50658396e-02,   1.11942998e-02,
#          4.28554025e-03,   2.27364381e-02,   9.12463989e-03,
#          1.80190991e-02,   1.26348325e-02,   8.48901587e-01,
#          1.99878270e-02,   3.84590151e-01,   2.20951524e-02,
#          2.15488180e-02,   1.24084509e-01,   1.54629493e-02,
#          1.87330908e-02,   1.27271600e-02,   8.87589099e-03,
#          1.32648897e-02,   2.41849075e-02,   2.08277038e-03,
#          1.38745827e-02,   3.24509598e-02,   5.53171813e-03,
#          2.50757924e-02,   1.96268180e-02,   1.42078714e-02,
#          2.00400443e-02,   5.05920810e-03,   1.49295917e-02,
#          1.04182293e-02,   8.62293157e-03,   1.76625248e-02,
#          2.25358191e-02,   2.59416350e-02,   1.60970783e-02,
#          2.33023626e-02,   1.50906779e-02,   6.29681604e-03,
#          1.97481881e-02,   1.28002617e-02,   1.21672720e-02,
#          4.61371209e-03,   1.80695367e-02,   7.39363759e-03,
#          2.18338851e-02,   1.98451703e-02,   3.78559995e-03,
#          1.11407212e-02,   9.23217297e-03,   3.14474453e-04,
#          1.13133475e-02,   9.87971010e-03,   1.09871764e-02,
#          5.00901913e-03,   6.59829009e-03,   7.13069998e-03,
#          8.72165097e-03,   3.33421688e-03,   1.20770913e-02,
#          1.37650707e-02,   4.70281153e-03,   3.17846101e-03,
#          4.01106496e-03,   5.47661973e-03,   2.98790237e-03,
#          5.05597038e-03,   3.70975279e-03,   7.52012813e-03,
#          3.39452878e-03,   4.08503812e-02,   1.05128214e-02,
#          1.27591663e-02,   6.11088685e-03,   1.38108700e-02,
#          1.06075857e-02,   9.88880450e-04,   2.42676706e-02,
#          1.44310465e-03])

# %%
plot_eps(247209)
# Out:
# arxiv_id                                       cond-mat/9602137
# categories                                             cond-mat
# title         Novel Symmetry Classes in Mesoscopic Normal-Su...
# date                                                 1996-02-27
# Name: 247209, dtype: object
# cond-mat

# %% [markdown]
# * try to back up this 'anomalous' behaviour by estimating the number of citations we'd expect.

# %% [markdown]
# try to look at most 'popular' papers in condensed matter (epsilon should correspond to clicks?)

# %%
top = epsilon_categories.sort(columns='cond-mat', ascending=False)['cond-mat']

# %%
top = top[0:10]

# %%
for ID, eps in zip(top.index, top):
    print id2title[ID], ID, eps
# Out:
# One-Dimensional Fermi liquids 35668 15.0986737302
# Path Integral Methods and Applications 28931 15.0187686176
# The Hubbard Model: Some Rigorous Results and Open Problems 82125 13.2950432691
# Bosonization for Beginners --- Refermionization for Experts 17195 10.8385363643
# The one-dimensional Hubbard model: A reminiscence 14514 8.62245636276
# Quantum phase transitions 143163 8.41088201445
# A practical guide to computer simulations 289638 8.20847390957
# An Introduction into the Feynman Path Integral 152 8.14035998228
# An introduction to bosonization 101172 7.08079654384
# Conformal Field Theory Approach to the Kondo Effect 206613 6.9861783062

# %% [markdown]
# good - epsilon now corresponds to popularity

# %%
plot_eps(643098)
# Out:
# A Heawood-type result for the algebraic connectivity of graphs on surfaces
# math.CO

# %% [markdown]
# this is an article that attracts people in condensed matter and unusually so

# %%
plot_eps(571709)
# Out:
# Elliptic mod \ell Galois representations which are not minimally elliptic
# math.NT

# %%
plot_eps(229777)
# Out:
# On the Euclidean Version of the Photon Number Integral
# math-ph

# %% [markdown]
# look at norm of epsilon to see if it correlates to popularity

# %%
epsilon_norm = np.sqrt(np.square(epsilon_categories).sum(axis=1))

# %%
epsilon_norm.sort(ascending=False)

# %%
for ID, eps in zip(epsilon_norm[0:10].index, epsilon_norm[0:10]):
    print ID, eps, id2title[ID]
# Out:
# 2272 56.947579542 Measurement of the neutrino velocity with the OPERA detector in the CNGS beam
# 10835 52.6611464685 A Supersymmetry Primer
# 4994 52.4591376179 The entropy formula for the Ricci flow and its geometric applications
# 14983 47.2904313441 Large N Field Theories, String Theory and Gravity
# 3023 45.993328836 Invariant Mass Distribution of Jet Pairs Produced in Association with a W boson in ppbar Collisions at sqrt(s) = 1.96 TeV
# 2267 43.7323801259 Anti De Sitter Space And Holography
# 11694 42.2778728287 Ricci flow with surgery on three-manifolds
# 8176 41.7920627944 The Large N Limit of Superconformal Field Theories and Supergravity
# 174 38.5184016714 Wilkinson Microwave Anisotropy Probe (WMAP) Three Year Results: Implications for Cosmology
# 16341 36.3715986563 Finite extinction time for the solutions to the Ricci flow on certain three-manifolds

# %% [markdown]
# the proof of innocence is one of the most popular articles on the arxiv in terms of clicks (major press coverage, etc)

# %%
id2item[id2item.arxiv_id == '1204.0162']
# Out:
#         arxiv_id                      categories                   title  \
# 13057  1204.0162  physics.pop-ph physics.data-an  The Proof of Innocence
#
#              date
# 13057  2012-04-01

# %%
plot_eps(13057)
# Out:
# The Proof of Innocence
# physics.data-an

# %% [markdown]
# look at some highly-cited papers (via https://www.quora.com/What-are-some-of-the-most-cited-papers-from-arXiv)
#
# one of the most cited papers in physics: 9711200

# %%
id2item[id2item.arxiv_id == 'hep-th/9711200']
# Out:
#             arxiv_id categories  \
# 8176  hep-th/9711200     hep-th
#
#                                                   title        date
# 8176  The Large N Limit of Superconformal Field Theo...  1997-11-27

# %%
plot_eps(8176)
# Out:
# The Large N Limit of Superconformal Field Theories and Supergravity
# hep-th

# %% [markdown]
# this is OK, but doesn't really capture inderdisciplinary interest.

# %%
lst = ['astro-ph/9812133', 'astro-ph/9805201', 'astro-ph/0302209']

# %%
idlist = []
for idx in range(0,len(lst)):
    idlist.append(id2item[id2item.arxiv_id == lst[idx]].index[0])

# %%
idlist
# Out:
# [5065, 15852, 104]

# %%
for idx in idlist:
    plot_eps(idx)
    plt.show()
    plt.close()
# Out:
# arxiv_id                                       astro-ph/9812133
# categories                               astro-ph hep-ex hep-ph
# title         Measurements of Omega and Lambda from 42 High-...
# date                                                 1998-12-07
# Name: 5065, dtype: object
# arxiv_id                                       astro-ph/9805201
# categories                                             astro-ph
# title         Observational Evidence from Supernovae for an ...
# date                                                 1998-05-14
# Name: 15852, dtype: object
# arxiv_id                                       astro-ph/0302209
# categories                                             astro-ph
# title         First Year Wilkinson Microwave Anisotropy Prob...
# date                                                 2003-02-11
# Name: 104, dtype: object

# %% [markdown]
# ^ this is good: captures interest in the appropriate categories!

# %% [markdown]
# look at histogram for papers in categories

# %%
theta_categories = pd.DataFrame(data=theta, columns=category_list)

# %%
theta_categories.sum().plot(kind='bar',figsize=(30, 4), title='number of papers in each arxiv category')

# %% [markdown]
# which categories have the most 'surprise'? i.e., the highest average theta?

# %%
epsilon_describe = epsilon_categories.describe()

# %%
epsilon_describe
# Out:
#             acc-phys       adap-org       alg-geom         ao-sci  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.000397       0.004488       0.009155       0.000146
# std         0.000172       0.002633       0.003966       0.000154
# min         0.000392       0.004408       0.008935       0.000143
# 25%         0.000394       0.004436       0.008986       0.000144
# 50%         0.000395       0.004456       0.009027       0.000145
# 75%         0.000398       0.004489       0.009095       0.000146
# max         0.099943       1.437330       0.878982       0.068097
#
#             astro-ph    astro-ph.CO    astro-ph.EP    astro-ph.GA  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.079975       0.034101       0.013193       0.025115
# std         0.356219       0.199619       0.089457       0.135110
# min         0.010505       0.004270       0.005480       0.007149
# 25%         0.010512       0.004272       0.005487       0.007156
# 50%         0.010572       0.004282       0.005496       0.007166
# 75%         0.010960       0.004378       0.005530       0.007242
# max        37.045288      23.066647       7.863973       7.654246
#
#          astro-ph.HE    astro-ph.IM      ...             q-fin.TR  \
# count  806139.000000  806139.000000      ...        806139.000000
# mean        0.028822       0.012223      ...             0.003425
# std         0.153835       0.067661      ...             0.002365
# min         0.006170       0.008137      ...             0.003335
# 25%         0.006176       0.008154      ...             0.003354
# 50%         0.006194       0.008176      ...             0.003368
# 75%         0.006299       0.008302      ...             0.003391
# max         9.656222      10.899772      ...             0.656660
#
#             quant-ph       solv-int        stat.AP        stat.CO  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.065172       0.010417       0.012819       0.006291
# std         0.328855       0.002438       0.018271       0.009281
# min         0.008875       0.010198       0.012492       0.005958
# 25%         0.008891       0.010266       0.012557       0.005988
# 50%         0.008945       0.010320       0.012608       0.006010
# 75%         0.009124       0.010420       0.012692       0.006048
# max        27.446476       0.883993      13.902493       1.344002
#
#              stat.ME        stat.ML        stat.OT        stat.TH  \
# count  806139.000000  806139.000000  806139.000000  806139.000000
# mean        0.014428       0.012262       0.000983       0.026668
# std         0.016008       0.036973       0.000192       0.037994
# min         0.013597       0.010399       0.000970       0.023884
# 25%         0.013659       0.010440       0.000976       0.023986
# 50%         0.013706       0.010470       0.000980       0.024067
# 75%         0.013787       0.010523       0.000986       0.024213
# max         2.641249       4.189933       0.108122       4.693662
#
#             supr-con
# count  806139.000000
# mean        0.001434
# std         0.000174
# min         0.001415
# 25%         0.001423
# 50%         0.001429
# 75%         0.001439
# max         0.113408
#
# [8 rows x 166 columns]

# %%
epsilon_describe.iloc[7,:].plot(kind='bar', figsize=(30, 4), title='maximum epsilon per category')

# %%
epsilon_describe.iloc[1,:].plot(kind='bar', figsize=(30, 4), title='mean epsilon per category')

# %%
epsilon_describe.iloc[2,:].plot(kind='bar', figsize=(30, 4), title='epsilon std per category')

# %%
epsilon_describe.iloc[3,:].plot(kind='bar', figsize=(30, 4), title='epsilon min per category')

# %% [markdown]
# plot epsilon min and number of papers per category

# %%
eps_min = epsilon_describe.iloc[3,:]

# %%
num_articles_per_category = theta_categories.sum()

# %%
eps_min_and_num = pd.concat([eps_min, num_articles_per_category], axis=1).T

# %%
eps_min_and_num.index = ['min', 'num_articles']

# %%
eps_min_and_num.T.plot(kind='bar', figsize=(30, 4), title='minimum epsilon and number of articles per category', logy=True)
